# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import RobustScaler
from sklearn.feature_selection import SelectKBest, f_regression

pd.set_option('max.columns', 100)

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

plt.rcParams['font.family'] = 'AppleGothic'
matplotlib.rcParams['axes.unicode_minus'] = False
plt.style.use('ggplot')
# %matplotlib inline

import warnings
warnings.filterwarnings(action = 'ignore')

from scipy import stats

# %%
def barplot(column):
    sns.barplot(data = data_feature, x = column, y = 'SalePrice')

# %%
# 데이터 확인
raw_data = pd.read_csv('train.csv')

print('Shape of Data :', raw_data.shape, '\n')
print('-' * 50)
print(raw_data.info())
# Out:
# Shape of Data : (1460, 81)
#
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB
# None

# %%
object_list = ['Alley', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 
               'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 
               'PoolQC', 'Fence', 'MiscFeature']

# 원래 데이터를 보존하기 위해 새로운 DataFrame 생성
modify_data = raw_data.copy()

# 결측치를 의미하지 않는 값에 'No have' 채워넣기
for feature in object_list:
    null_data = modify_data[feature].isnull().sum()
    print('Number of null values of {} *Before Modify* :'.format(feature), null_data, '\n')
    
    modify_data.loc[modify_data[feature].isnull(), feature] = 'No have'
    
    null_data = modify_data[feature].isnull().sum()
    print('Number of null values of {} *After Modify* :'.format(feature), null_data)
    print('-' * 60)
# Out:
# Number of null values of Alley *Before Modify* : 1369
#
# Number of null values of Alley *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of BsmtQual *Before Modify* : 37
#
# Number of null values of BsmtQual *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of BsmtCond *Before Modify* : 37
#
# Number of null values of BsmtCond *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of BsmtExposure *Before Modify* : 38
#
# Number of null values of BsmtExposure *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of BsmtFinType1 *Before Modify* : 37
#
# Number of null values of BsmtFinType1 *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of BsmtFinType2 *Before Modify* : 38
#
# Number of null values of BsmtFinType2 *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of FireplaceQu *Before Modify* : 690
#
# Number of null values of FireplaceQu *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of GarageType *Before Modify* : 81
#
# Number of null values of GarageType *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of GarageFinish *Before Modify* : 81
#
# Number of null values of GarageFinish *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of GarageQual *Before Modify* : 81
#
# Number of null values of GarageQual *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of GarageCond *Before Modify* : 81
#
# Number of null values of GarageCond *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of PoolQC *Before Modify* : 1453
#
# Number of null values of PoolQC *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of Fence *Before Modify* : 1179
#
# Number of null values of Fence *After Modify* : 0
# ------------------------------------------------------------
# Number of null values of MiscFeature *Before Modify* : 1406
#
# Number of null values of MiscFeature *After Modify* : 0
# ------------------------------------------------------------

# %%
print('Number of null values of GarageYrBlt *Before Modify* :', modify_data['GarageYrBlt'].isnull().sum(), '\n')

# 결측치 대체
modify_data.loc[modify_data['GarageYrBlt'].isnull(), 'GarageYrBlt'] = 0
print('Number of null values of GarageYrBlt *After Modify* :', modify_data['GarageYrBlt'].isnull().sum())
# Out:
# Number of null values of GarageYrBlt *Before Modify* : 81
#
# Number of null values of GarageYrBlt *After Modify* : 0

# %%
print('Number of null values of MasVnrType *Before* :', modify_data['MasVnrType'].isnull().sum(), '\n')
print('Number of null values of MasVnrArea *Before* :', modify_data['MasVnrArea'].isnull().sum(), '\n')
print('Number of null values of Electrical *Before* :', modify_data['Electrical'].isnull().sum(), '\n')

modify_data['MasVnrType'].fillna('None', inplace = True)
modify_data['MasVnrArea'].fillna(0, inplace = True)
modify_data['Electrical'].fillna(modify_data['Electrical'].mode()[0], inplace = True)

print('Number of null values of MasVnrType *After* :', modify_data['MasVnrType'].isnull().sum(), '\n')
print('Number of null values of MasVnrArea *After* :', modify_data['MasVnrArea'].isnull().sum(), '\n')
print('Number of null values of Electrical *After* :', modify_data['Electrical'].isnull().sum())
# Out:
# Number of null values of MasVnrType *Before* : 8
#
# Number of null values of MasVnrArea *Before* : 8
#
# Number of null values of Electrical *Before* : 1
#
# Number of null values of MasVnrType *After* : 0
#
# Number of null values of MasVnrArea *After* : 0
#
# Number of null values of Electrical *After* : 0

# %%
# 'LotFrontage' 결측치를 대체해주는 함수 만들기
def imputer_lotfrontage(raw_data):
    
    print('Number of null values of LotFrontage *Before Modify* :', raw_data['LotFrontage'].isnull().sum(), '\n')
    
    # 'KNNImputer' 라이브러리 불러오기
    from sklearn.impute import KNNImputer
    
    # 'LotFrontage' 변수에 결측치를 가지는 'Id' 추출 후 저장
    miss_id = raw_data[raw_data['LotFrontage'].isnull()]['Id'].unique()
    
    # 'Id', 'LotFrontage', 'LotArea' 변수 추출 후 저장
    data = raw_data[['Id', 'LotFrontage', 'LotArea']]
    
    # 'LotFrontage' 변수의 값이 300 넘는 관측치를 삭제하기로 했으므로 삭제
    outlier_id = data[data['LotFrontage'] > 300]['Id']
    data = data[~data['Id'].isin(outlier_id)]
    
    # 'Id' 변수를 인덱스로 지정
    data = data.set_index('Id')
    
    # 'LotArea' 변수를 로그화 수행 후, 변수 삭제
    data['LotLogArea'] = data['LotArea'].apply(lambda x: np.log(x))
    data = data.drop('LotArea', axis = 1)
    
    # 모델 객체 생성 후 학습시키고 DataFrame으로 저장
    # 원본 데이터에 결측치로 기입되어 있는 관측치들만 수정해주기 위해 DataFrame을 만들 때, 인덱스를 위 데이터의 인덱스로 지정
    imputer = KNNImputer(n_neighbors = 5)
    pre_data = pd.DataFrame(imputer.fit_transform(data), columns = data.columns, index = data.index)
    
    # 결측치가 존재하던 관측치만 저장
    pre_data = pre_data[pre_data.index.isin(miss_id)]
    
    # 원본 데이터 결측치를 대입해주는 과정
    for id_value, lot_value in zip(pre_data.index, pre_data['LotFrontage']):
        for index in raw_data.index:
            
            if raw_data.loc[index, 'Id'] == id_value:
                raw_data.loc[index, 'LotFrontage'] = lot_value
    
    print('Number of null values of LotFrontage *After Modify* :', raw_data['LotFrontage'].isnull().sum())
 
    return raw_data

# %%
# 생성한 함수 적용
modify_data = imputer_lotfrontage(modify_data)
# Out:
# Number of null values of LotFrontage *Before Modify* : 259
#
# Number of null values of LotFrontage *After Modify* : 0

# %%
# 우선 원래 데이터를 보존하기 위해 데이터 복사
final_data = modify_data.copy()

# 'ExterQual' & 'ExterCond'
mapping = {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1}

final_data['ExterQual'] = final_data['ExterQual'].map(mapping)
final_data['ExterCond'] = final_data['ExterCond'].map(mapping)

# 'BsmtQual' & 'BsmtCond'
mapping = {'No have' : 0, 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5}

final_data['BsmtQual'] = final_data['BsmtQual'].map(mapping)
final_data['BsmtCond'] = final_data['BsmtCond'].map(mapping)

# 'HeatingQC'
mapping = {'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5}

final_data['HeatingQC'] = final_data['HeatingQC'].map(mapping)

# 'KitchenQual'
mapping = {'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5}

final_data['KitchenQual'] = final_data['KitchenQual'].map(mapping)

# 'FireplaceQu'
mapping = mapping = {'No have' : 0, 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5}

final_data['FireplaceQu'] = final_data['FireplaceQu'].map(mapping)

# 'GarageQual' & 'GarageCond'
mapping = mapping = {'No have' : 0, 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5}

final_data['GarageQual'] = final_data['GarageQual'].map(mapping)
final_data['GarageCond'] = final_data['GarageCond'].map(mapping)

# 'PoolQC'
mapping = mapping = {'No have' : 0, 'Fa' : 1, 'TA' : 2, 'Gd' : 3, 'Ex' : 4}

final_data['PoolQC'] = final_data['PoolQC'].map(mapping)

# %%
# 'NewLotShape' 변수 생성
print('Shape of final_data *Before Create* :', final_data.shape, '\n')

final_data['NewLotShape'] = np.nan

for index in final_data.index:
    
    value = final_data.loc[index, 'LotShape']
    
    if value == 'Reg':
        final_data.loc[index, 'NewLotShape'] = 'Reg'
        
    else:
        final_data.loc[index, 'NewLotShape'] = 'IR'
        
print('Shape of final_data *After Create* :', final_data.shape, '\n')
print('Unique of values of NewLotShape :', final_data['NewLotShape'].unique())
# Out:
# Shape of final_data *Before Create* : (1460, 81)
#
# Shape of final_data *After Create* : (1460, 82)
#
# Unique of values of NewLotShape : ['Reg' 'IR']

# %%
print('Number of incorrectly entered value *Wd Shng* :',
      len(modify_data[modify_data['Exterior2nd'] == 'Wd Shng']), '\n')

print('Number of incorrectly entered value *CmentBd* :',
      len(modify_data[modify_data['Exterior2nd'] == 'CmentBd']), '\n')

print('Number of incorrectly entered value *Brk Cmn* :',
      len(modify_data[modify_data['Exterior2nd'] == 'Brk Cmn']))
# Out:
# Number of incorrectly entered value *Wd Shng* : 38
#
# Number of incorrectly entered value *CmentBd* : 60
#
# Number of incorrectly entered value *Brk Cmn* : 7

# %%
modify_data.loc[modify_data['Exterior2nd'] == 'Wd Shng', 'Exterior2nd'] = 'Wd Sdng'
modify_data.loc[modify_data['Exterior2nd'] == 'CmentBd', 'Exterior2nd'] = 'CemntBd'
modify_data.loc[modify_data['Exterior2nd'] == 'Brk Cmn', 'Exterior2nd'] = 'BrkComm'

print('Number of incorrectly entered value *Wd Shng* :',
      len(modify_data[modify_data['Exterior2nd'] == 'Wd Shng']), '\n')

print('Number of incorrectly entered value *CmentBd* :',
      len(modify_data[modify_data['Exterior2nd'] == 'CmentBd']), '\n')

print('Number of incorrectly entered value *Brk Cmn* :',
      len(modify_data[modify_data['Exterior2nd'] == 'Brk Cmn']))
# Out:
# Number of incorrectly entered value *Wd Shng* : 0
#
# Number of incorrectly entered value *CmentBd* : 0
#
# Number of incorrectly entered value *Brk Cmn* : 0

# %%
print('Shape of final_data *Before Create* :', final_data.shape, '\n')

# 'NewCondition1' 변수 생성
final_data['NewCondition1'] = np.nan

for index in final_data.index:
    
    value = final_data.loc[index, 'Condition1']
    
    if (value == 'Artery') | (value == 'Feedr'):
        final_data.loc[index, 'NewCondition1'] = 'Street'
        
    elif (value == 'PosN') | (value == 'PosA'):
        final_data.loc[index, 'NewCondition1'] = 'Positive'
        
    elif value == 'Norm':
        final_data.loc[index, 'NewCondition1'] = 'Norm'
        
    else:
        final_data.loc[index, 'NewCondition1'] = 'Rail'
        
print('Unique values of NewCondition1 :', final_data['NewCondition1'].unique(), '\n')

# 'CountCon' 변수 생성
final_data['CountCon'] = np.nan

for index in final_data.index:
    
    first_value = modify_data.loc[index, 'Condition1']
    second_value = modify_data.loc[index, 'Condition2']
    
    # 'Condition1'과 'Condition2' 변수 모두 'Norm'인 경우
    if (first_value == 'Norm') & (second_value == 'Norm'):
        final_data.loc[index, 'CountCon'] = 0
    
    else:
        final_data.loc[index, 'CountCon'] = 1

print('Unique values of CountCon :', final_data['CountCon'].unique(), '\n')
print('Shape of final_data *After Create* :', final_data.shape)
# Out:
# Shape of final_data *Before Create* : (1460, 82)
#
# Unique values of NewCondition1 : ['Norm' 'Street' 'Positive' 'Rail']
#
# Unique values of CountCon : [0. 1.]
#
# Shape of final_data *After Create* : (1460, 84)

# %%
# 'SameExterior' 변수 생성
print('Shape of final_data *Before Create* :', final_data.shape, '\n')

final_data['SameExterior'] = np.nan

for index in final_data.index:
    
    first_exterior = final_data.loc[index, 'Exterior1st']
    second_exterior = final_data.loc[index, 'Exterior2nd']
    
    if first_exterior == second_exterior:
        final_data.loc[index, 'SameExterior'] = 1
    
    else:
        final_data.loc[index, 'SameExterior'] = 0
        
print('Shape of final_data *After Create* :', final_data.shape, '\n')
print('Unique vlaues of SameExterior :', final_data['SameExterior'].unique())
# Out:
# Shape of final_data *Before Create* : (1460, 84)
#
# Shape of final_data *After Create* : (1460, 85)
#
# Unique vlaues of SameExterior : [1. 0.]

# %%
# 'LotFrontage' 변수의 결측치를 예측하기 위한 변수 추출
miss_list = ['Id', 'MSSubClass', 'MSZoning', 'LotShape', 'LotConfig', '1stFlrSF', 
             'BldgType', 'GrLivArea', 'LotArea', 'LotFrontage']

# 데이터 추출
miss_data = modify_data[miss_list]

print('Shape of miss_data :', miss_data.shape)
miss_data.head()
# Out:
# Shape of miss_data : (1460, 10)
#    Id  MSSubClass MSZoning LotShape LotConfig  1stFlrSF BldgType  GrLivArea  \
# 0   1          60       RL      Reg    Inside       856     1Fam       1710
# 1   2          20       RL      Reg       FR2      1262     1Fam       1262
# 2   3          60       RL      IR1    Inside       920     1Fam       1786
# 3   4          70       RL      IR1    Corner       961     1Fam       1717
# 4   5          60       RL      IR1       FR2      1145     1Fam       2198
#
#    LotArea  LotFrontage
# 0     8450         65.0
# 1     9600         80.0
# 2    11250         68.0
# 3     9550         60.0
# 4    14260         84.0

# %%
outlier_id = miss_data[miss_data['LotFrontage'] > 300]['Id']

# 'LotFrontage' 변수의 값이 300 넘는 관측치 삭제
miss_data = miss_data[~miss_data['Id'].isin(outlier_id)]
miss_data.reset_index(drop = True, inplace = True)

# 'NewLotShape' 변수 생성
print('Shape of miss_data *Before Create* :', miss_data.shape, '\n')

miss_data['NewLotShape'] = np.nan

for index in miss_data.index:
    
    if miss_data.loc[index, 'LotShape'] == 'Reg':
        miss_data.loc[index, 'NewLotShape'] = 'Reg'
        
    else:
        miss_data.loc[index, 'NewLotShape'] = 'Irreg'
        
print('Shape of miss_data *After Create* :', miss_data.shape, '\n')
print('Unique value of NewLotShape :', miss_data['NewLotShape'].unique())
# Out:
# Shape of miss_data *Before Create* : (1458, 10)
#
# Shape of miss_data *After Create* : (1458, 11)
#
# Unique value of NewLotShape : ['Reg' 'Irreg']

# %%
# 연속형 변수를 로그화
miss_data['Log1stFlrSF'] = miss_data['1stFlrSF'].apply(lambda x: np.log1p(x))
miss_data['LogGrLivArea'] = miss_data['GrLivArea'].apply(lambda x: np.log1p(x))
miss_data['LogLotArea'] = miss_data['LotArea'].apply(lambda x: np.log1p(x))

# 로그화 수행 뒤 Heatmap
corr_data = miss_data[['1stFlrSF', 'GrLivArea', 'LotArea', 'Log1stFlrSF',
                       'LogGrLivArea', 'LogLotArea', 'LotFrontage']].corr()

# 'mask' 옵션 설정
mask = np.zeros_like(corr_data, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

# 시각화 과정
plt.figure(figsize = (10, 8))

sns.heatmap(corr_data, mask = mask, cmap = 'Blues', linewidth = 0.5, annot = True, fmt = ".2f")
# Out:
# findfont: Font family ['AppleGothic'] not found. Falling back to DejaVu Sans.
# <AxesSubplot:>

# %%
# 우선 결측치를 없애고 사용하고자 하는 변수 추출
value_list = ['Id', 'MSSubClass', 'MSZoning', 'NewLotShape', 'LotConfig', 'BldgType',
             'Log1stFlrSF', 'GrLivArea', 'LogLotArea', 'LotFrontage']

pre_miss_data = miss_data[~miss_data['LotFrontage'].isnull()][value_list]
print('Shpae of pre_miss_data :', pre_miss_data.shape)

# 'MSSubClass' 변수 문자형 타입으로 변환
pre_miss_data['MSSubClass'] = pre_miss_data['MSSubClass'].astype('str')

pre_miss_data.head()
# Out:
# Shpae of pre_miss_data : (1458, 10)
#    Id MSSubClass MSZoning NewLotShape LotConfig BldgType  Log1stFlrSF  \
# 0   1         60       RL         Reg    Inside     1Fam     6.753438
# 1   2         20       RL         Reg       FR2     1Fam     7.141245
# 2   3         60       RL       Irreg    Inside     1Fam     6.825460
# 3   4         70       RL       Irreg    Corner     1Fam     6.869014
# 4   5         60       RL       Irreg       FR2     1Fam     7.044033
#
#    GrLivArea  LogLotArea  LotFrontage
# 0       1710    9.042040         65.0
# 1       1262    9.169623         80.0
# 2       1786    9.328212         68.0
# 3       1717    9.164401         60.0
# 4       2198    9.565284         84.0

# %%
# RandomFroestRegressor 수행
data = pd.get_dummies(pre_miss_data, drop_first = True)

X = data.drop(['Id', 'LotFrontage'], axis = 1)
y = data['LotFrontage']

rf_model = RandomForestRegressor(random_state = 1025).fit(X, y)

# %%
# 변수의 중요도 시각화
feature_data = pd.DataFrame(rf_model.feature_importances_, index = X.columns, columns = ['Importance'])

plt.figure(figsize = (16, 5))

plot_data = feature_data.sort_values(by = 'Importance', ascending = False)

sns.barplot(x = plot_data.index, y = 'Importance', data = plot_data)
plt.xticks(rotation = 30)
plt.ylabel('')
plt.show()

# %%
# 'LotFrontage' 결측치를 대체해주는 함수 만들기
def imputer_lotfrontage(raw_data):
    
    # 'KNNImputer' 라이브러리 불러오기
    from sklearn.impute import KNNImputer
    
    # 'LotFrontage' 변수에 결측치를 가지는 'Id' 추출 후 저장
    miss_id = raw_data[raw_data['LotFrontage'].isnull()]['Id'].unique()
    
    # 'Id', 'LotFrontage', 'LotArea' 변수 추출 후 저장
    data = raw_data[['Id', 'LotFrontage', 'LotArea']]
    
    # 'LotFrontage' 변수의 값이 300 넘는 관측치를 삭제하기로 했으므로 삭제
    outlier_id = data[data['LotFrontage'] > 300]['Id']
    data = data[~data['Id'].isin(outlier_id)]
    
    # 'Id' 변수를 인덱스로 지정
    data = data.set_index('Id')
    
    # 'LotArea' 변수를 로그화 수행 후, 변수 삭제
    data['LotLogArea'] = data['LotArea'].apply(lambda x: np.log(x))
    data = data.drop('LotArea', axis = 1)
    
    # 모델 객체 생성 후 학습시키고 DataFrame으로 저장
    # 원본 데이터에 결측치로 기입되어 있는 관측치들만 수정해주기 위해 DataFrame을 만들 때, 인덱스를 위 데이터의 인덱스로 지정
    imputer = KNNImputer(n_neighbors = 5)
    pre_data = pd.DataFrame(imputer.fit_transform(data), columns = data.columns, index = data.index)
    
    # 결측치가 존재하던 관측치만 저장
    pre_data = pre_data[pre_data.index.isin(miss_id)]
    
    # 원본 데이터 결측치를 대입해주는 과정
    for id_value, lot_value in zip(pre_data.index, pre_data['LotFrontage']):
        for index in raw_data.index:
            
            if raw_data.loc[index, 'Id'] == id_value:
                raw_data.loc[index, 'LotFrontage'] = lot_value
    
    return raw_data

# %%
print('Number of null values of LotFrontage *Before* :', modify_data['LotFrontage'].isnull().sum(), '\n')

# 생성해준 함수 적용
modify_data = imputer_lotfrontage(modify_data)
print('Number of null values of LotFrontage *After* :', modify_data['LotFrontage'].isnull().sum())
# Out:
# Number of null values of LotFrontage *Before* : 0
#
# Number of null values of LotFrontage *After* : 0

# %%
train = final_data

# %%
train.isna().sum().sum()
# Out:
# 0

# %%
train['BsmtExposure'].value_counts()
# Out:
# No         953
# Av         221
# Gd         134
# Mn         114
# No have     38
# Name: BsmtExposure, dtype: int64

# %%
train.MSSubClass=train.MSSubClass.astype('object')

# %%
train=train.drop('Utilities', axis = 1)

# %%
mapping = {'No have':0,'No':1, 'Mn':2, 'Av':3, 'Gd':4}
train['BsmtExposure'] = train['BsmtExposure'].map(mapping)

# %%
mapping = {'No have':0,'LwQ':1, 'Rec':2,'BLQ':3,'ALQ':4,'Unf':5,'GLQ':6}
train['BsmtFinType1'] = train['BsmtFinType1'].map(mapping)
train['BsmtFinType2'] = train['BsmtFinType2'].map(mapping)

# %%
mapping = {'Y':1, 'N':0}
train['CentralAir'] = train['CentralAir'].map(mapping)

# %%
mapping = {'No have':0,'Unf':1, 'RFn':2, 'Fin':3}
train['GarageFinish'] = train['GarageFinish'].map(mapping)

# %%
mapping = {'N':0,'P':1,'Y':2}
train['PavedDrive'] = train['PavedDrive'].map(mapping)

# %%
mapping = {'No have':0,'MnWw':1,'GdWo':2,'MnPrv':3,'GdPrv':4}
train['Fence'] = train['Fence'].map(mapping)

# %%
train['remodeling'] = 0
for i in train.index:
    if train.loc[i,'YearBuilt'] == train.loc[i,'YearRemodAdd']:
        train.loc[i,'remodeling'] = 0
    else:
        train.loc[i,'remodeling'] = 1

# %%
sns.scatterplot(data = train, x = 'YearBuilt', y = 'SalePrice', hue = 'remodeling')
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>
# findfont: Font family ['AppleGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# - 1940년도에 지어진 건물은 거의다 remodeling을 했다.

# %%
train_remodeling_1 = train[train['remodeling'] == 1]
train_remodeling_0 = train[train['remodeling'] == 0]

fig, ax = plt.subplots(nrows = 2, figsize = (16,8))
sns.scatterplot(data = train_remodeling_1, x = 'YearBuilt', y = 'SalePrice', ax = ax[0])
ax[0].set_title('remodeling')

sns.scatterplot(data = train_remodeling_0, x = 'YearBuilt', y = 'SalePrice', color = 'b',ax =ax [1])
ax[1].set_title('non remodeling')
# Out:
# Text(0.5, 1.0, 'non remodeling')
# findfont: Font family ['AppleGothic'] not found. Falling back to DejaVu Sans.

# %%
sns.boxenplot(data = train, x = 'remodeling', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='remodeling', ylabel='SalePrice'>

# %% [markdown]
# - 0의 SalePrice가 높게 나오는데 이것은 신축 건물들의 가격이 높아서 라고 예상하고 있다.
# - 그러면 우리는 리모델링은 10년정도 이후에 해야 한다고 가정하고 리모델링 가격이 영향을 미치는 지 미치지 않는지 확인하기 위해서
# - 1940~ 2000까지의 데이터를 가지고 remodeling여부를 판별해주자.

# %%
train['Year_1950'] = train['YearBuilt'].apply(lambda x: 1 if x >= 1950 else 0)
sns.boxenplot(data = train, x = 'Year_1950', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='Year_1950', ylabel='SalePrice'>

# %% [markdown]
# - 확실히 1950년도 이전의 건물과 이후의 건물은 가격면에서 차이가 있다.
# - 그러면 우리는 데이터를 범주화 해주도록 하자.
# - 1. 1950년 이전의 건물을 0
# - 2. 1950년 이후의 건물 중 리모델링을 안한 건물 1
# - 3. 1950년 이후에 건물 중 리모델링을 한 건물 2

# %%
train['New_Year_feature'] = np.nan
for i in train.index:
    # 처음에 1950년도 이전의 건물을 뽑아내서 0을 할당한다.
    if train.loc[i,'Year_1950'] == 0:
        train.loc[i,'New_Year_feature'] = 0
    else:
    # 1950년도 이상의 건물중에서 remodeling 값이 0이면 1 1이면 2를 할당한다.
        if train.loc[i,'remodeling'] == 0:
            train.loc[i,'New_Year_feature'] = 1
        else:
            train.loc[i,'New_Year_feature'] = 2

# %%
sns.boxenplot(data = train, x = 'New_Year_feature', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='New_Year_feature', ylabel='SalePrice'>

# %% [markdown]
# - 확연한 차이가 나는 것을 알 수 있다.

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice',
#        'NewLotShape', 'NewCondition1', 'CountCon', 'SameExterior',
#        'remodeling', 'Year_1950', 'New_Year_feature'],
#       dtype='object')

# %%
for i in train.index:
    train.loc[i,'BsmtBath_counts'] = train.loc[i,'BsmtFullBath']+train.loc[i,'BsmtHalfBath']
    train.loc[i,'Bath_counts'] = train.loc[i,'FullBath'] + train.loc[i,'HalfBath']
train = train.drop(['BsmtFullBath','BsmtHalfBath','FullBath','HalfBath'], axis = 1)

# %%
train['Bath_counts']
# Out:
# 0       3.0
# 1       2.0
# 2       3.0
# 3       1.0
# 4       3.0
#        ...
# 1455    3.0
# 1456    2.0
# 1457    2.0
# 1458    1.0
# 1459    2.0
# Name: Bath_counts, Length: 1460, dtype: float64

# %%
fig, ax = plt.subplots(ncols = 2, figsize = (16,8))
sns.boxenplot(data = train, x = 'BsmtBath_counts', y = 'SalePrice', ax = ax[0])
ax[0].set_title('BsmtBath_counts vs SalePrice')

sns.boxenplot(data = train, x = 'Bath_counts', y = 'SalePrice', ax = ax[1])
ax[1].set_title('Bath_counts vs SalePrice')
# Out:
# Text(0.5, 1.0, 'Bath_counts vs SalePrice')

# %%
train.GarageType.unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', 'No have', 'Basment',
#        '2Types'], dtype=object)

# %%
# CarPort와 Detchd는 집과 떨어진 주차장임으로 이것을 제외한 나머지는 Garage_in이라는 변수를 만들어주자.
sns.barplot(data = train, x = 'GarageType', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='GarageType', ylabel='SalePrice'>

# %%
train.loc[(train['GarageType'] != 'Detchd')& (train['GarageType'] != 'CarPort'),'Garage_in'] = 1
train.loc[(train['GarageType'] == 'Detchd')|(train['GarageType'] == 'CarPort'), 'Garage_in'] = 0

# %%
sns.barplot(data = train, x = 'Garage_in', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='Garage_in', ylabel='SalePrice'>

# %% [markdown]
# - GarageCond가 5인 것은 많이 없는것으로 보여진다. 그리고 scatterplot의 경우 오른쪽으로 치우쳐져 있다.
# - barplot을 통하여 알아보기로 하자.

# %%
sns.boxenplot(data = train, x = 'GarageCond', y = 'SalePrice')
# 4이상부터 떨어지는 경향이 있다.
# Out:
# <AxesSubplot:xlabel='GarageCond', ylabel='SalePrice'>

# %%
sns.scatterplot(data = train, x = 'GarageArea', y = 'SalePrice', hue = 'GarageCars')
# Out:
# <AxesSubplot:xlabel='GarageArea', ylabel='SalePrice'>

# %% [markdown]
# - 넓은 차고지를 갖고 있는 경우 많은 차를 주차할 수 있다.

# %%
train['Garage_exist'] = train['GarageYrBlt'].apply(lambda x:1 if x > 0 else 0)

# %% [markdown]
# - GarageYrBlt가 0 이상이면 1 아니면 0으로 바꿔주자.
# - 그러면 GarageYrBlt가 있는지 없는지 알 수 있다.

# %%
sns.boxenplot(data = train, x = 'Garage_exist', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='Garage_exist', ylabel='SalePrice'>

# %% [markdown]
# - Garage가 없는 것보다 있을 때 더 높은 가격을 가지고 가는 것을 확인할 수 있다.

# %%
train['MasVnrArea_exist'] = train['MasVnrArea'].apply(lambda x:1 if x > 0 else 0)
train=train.drop('MasVnrArea', axis = 1)

# %%
sns.boxenplot(data = train, x = 'MasVnrArea_exist', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='MasVnrArea_exist', ylabel='SalePrice'>

# %%
train['ScreenPorch_exist'] = train['ScreenPorch'].apply(lambda x:1 if x > 0 else 0)
sns.boxenplot(data = train, x = 'ScreenPorch_exist', y = 'SalePrice')
# ScreenPorch가 1인 데이터가 더 높은 가격을 형성하는 것을 볼 수 있다.
train=train.drop('ScreenPorch', axis = 1)

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BedroomAbvGr',
#        'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional',
#        'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal', 'MoSold',
#        'YrSold', 'SaleType', 'SaleCondition', 'SalePrice', 'NewLotShape',
#        'NewCondition1', 'CountCon', 'SameExterior', 'remodeling', 'Year_1950',
#        'New_Year_feature', 'BsmtBath_counts', 'Bath_counts', 'Garage_in',
#        'Garage_exist', 'MasVnrArea_exist', 'ScreenPorch_exist'],
#       dtype='object')

# %%
bsmt = ['BsmtQual', 'BsmtCond',
       'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF']

# %%
for i in train.index:
    train.loc[i,'BsmtArea'] = train.loc[i,'BsmtQual'] * train.loc[i,'TotalBsmtSF']
sns.scatterplot(data = train, x = 'BsmtArea', y = 'SalePrice')
train=train.drop(['BsmtQual','TotalBsmtSF'], axis =1)

# %% [markdown]
# - 지하실의 높이와 지하 총 평방피트를 곱해서 BsmtArea라는 지하의 넓이를 구해준다.

# %%
sns.scatterplot(data = train, x = 'BsmtArea', y = 'SalePrice', hue = 'BsmtCond')
# Out:
# <AxesSubplot:xlabel='BsmtArea', ylabel='SalePrice'>

# %%
a = []
for i in train.columns:
    if train[i].dtype == 'object':
        a.append(i)

# %%
le = LabelEncoder()
for i in a:
    train[i] = le.fit_transform(train[i])
    
train['SalePrice'] = train['SalePrice'].apply(lambda x: np.log1p(x))
train['LotArea'] = train['LotArea'].apply(lambda x:np.log1p(x))
train['GarageArea'] = train['GarageArea'].apply(lambda x:np.log1p(x))
train['GrLivArea'] = train['GrLivArea'].apply(lambda x:np.log1p(x))
train = train.drop(['remodeling','YearRemodAdd','Year_1950','Id'], axis = 1)
train = train.drop(['Exterior1st','Exterior2nd'], axis = 1)
train = train.drop(['GarageCars','Alley'], axis = 1)
train = train.drop(['Condition1','Condition2'], axis = 1)
train['LotFrontage'] = train['LotFrontage'].apply(lambda x: np.log1p(x))
train['BsmtArea'] = train['BsmtArea'].apply(lambda x: np.log1p(x))
quality_data=['OverallQual','ExterQual','KitchenQual','FireplaceQu','GarageQual']

train['quality'] = 0
for i in quality_data:
    train['quality'] += train[i].apply(lambda x: x/len(train[i].unique()))
    train=train.drop(i,axis = 1)

# %%
sns.scatterplot(data = train, x = 'quality', y = 'SalePrice')
print(train[['quality','SalePrice']].corr())
# Out:
#            quality  SalePrice
# quality    1.00000    0.82022
# SalePrice  0.82022    1.00000

# %% [markdown]
# - 강한 상관관계를 띄고 있으므로 변수로 채택하기로 하자.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 72 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MSSubClass         1460 non-null   int32
#  1   MSZoning           1460 non-null   int32
#  2   LotFrontage        1460 non-null   float64
#  3   LotArea            1460 non-null   float64
#  4   Street             1460 non-null   int32
#  5   LotShape           1460 non-null   int32
#  6   LandContour        1460 non-null   int32
#  7   LotConfig          1460 non-null   int32
#  8   LandSlope          1460 non-null   int32
#  9   Neighborhood       1460 non-null   int32
#  10  BldgType           1460 non-null   int32
#  11  HouseStyle         1460 non-null   int32
#  12  OverallCond        1460 non-null   int64
#  13  YearBuilt          1460 non-null   int64
#  14  RoofStyle          1460 non-null   int32
#  15  RoofMatl           1460 non-null   int32
#  16  MasVnrType         1460 non-null   int32
#  17  ExterCond          1460 non-null   int64
#  18  Foundation         1460 non-null   int32
#  19  BsmtCond           1460 non-null   int64
#  20  BsmtExposure       1460 non-null   int64
#  21  BsmtFinType1       1460 non-null   int64
#  22  BsmtFinSF1         1460 non-null   int64
#  23  BsmtFinType2       1460 non-null   int64
#  24  BsmtFinSF2         1460 non-null   int64
#  25  BsmtUnfSF          1460 non-null   int64
#  26  Heating            1460 non-null   int32
#  27  HeatingQC          1460 non-null   int64
#  28  CentralAir         1460 non-null   int64
#  29  Electrical         1460 non-null   int32
#  30  1stFlrSF           1460 non-null   int64
#  31  2ndFlrSF           1460 non-null   int64
#  32  LowQualFinSF       1460 non-null   int64
#  33  GrLivArea          1460 non-null   float64
#  34  BedroomAbvGr       1460 non-null   int64
#  35  KitchenAbvGr       1460 non-null   int64
#  36  TotRmsAbvGrd       1460 non-null   int64
#  37  Functional         1460 non-null   int32
#  38  Fireplaces         1460 non-null   int64
#  39  GarageType         1460 non-null   int32
#  40  GarageYrBlt        1460 non-null   float64
#  41  GarageFinish       1460 non-null   int64
#  42  GarageArea         1460 non-null   float64
#  43  GarageCond         1460 non-null   int64
#  44  PavedDrive         1460 non-null   int64
#  45  WoodDeckSF         1460 non-null   int64
#  46  OpenPorchSF        1460 non-null   int64
#  47  EnclosedPorch      1460 non-null   int64
#  48  3SsnPorch          1460 non-null   int64
#  49  PoolArea           1460 non-null   int64
#  50  PoolQC             1460 non-null   int64
#  51  Fence              1460 non-null   int64
#  52  MiscFeature        1460 non-null   int32
#  53  MiscVal            1460 non-null   int64
#  54  MoSold             1460 non-null   int64
#  55  YrSold             1460 non-null   int64
#  56  SaleType           1460 non-null   int32
#  57  SaleCondition      1460 non-null   int32
#  58  SalePrice          1460 non-null   float64
#  59  NewLotShape        1460 non-null   int32
#  60  NewCondition1      1460 non-null   int32
#  61  CountCon           1460 non-null   float64
#  62  SameExterior       1460 non-null   float64
#  63  New_Year_feature   1460 non-null   float64
#  64  BsmtBath_counts    1460 non-null   float64
#  65  Bath_counts        1460 non-null   float64
#  66  Garage_in          1460 non-null   float64
#  67  Garage_exist       1460 non-null   int64
#  68  MasVnrArea_exist   1460 non-null   int64
#  69  ScreenPorch_exist  1460 non-null   int64
#  70  BsmtArea           1460 non-null   float64
#  71  quality            1460 non-null   float64
# dtypes: float64(14), int32(23), int64(35)
# memory usage: 690.2 KB

# %%
target=train.loc[:,'SalePrice']
train = train.drop('SalePrice', axis = 1)

# %% [markdown]
# # 데이터 중요 feature 추출

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import StratifiedKFold, train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(train,target, test_size = 0.2, random_state = 42)

# %%
lr=LinearRegression()
lr.fit(X_train, y_train)
y_pred=lr.predict(X_test)

RMSE=mean_squared_error(y_pred, y_test)**0.5
print(RMSE)
# Out:
# 0.14498327033121763

# %%
import statsmodels.api as sm

X = sm.add_constant(X_train)
y = y_train

model = sm.OLS(y,X)
results = model.fit()
print(results.summary())
results.pvalues
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.887
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     121.1
# Date:                Mon, 10 May 2021   Prob (F-statistic):               0.00
# Time:                        22:12:18   Log-Likelihood:                 714.08
# No. Observations:                1168   AIC:                            -1284.
# Df Residuals:                    1096   BIC:                            -919.6
# Df Model:                          71
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 6.6137      6.437      1.027      0.304      -6.017      19.244
# MSSubClass           -0.0066      0.002     -2.732      0.006      -0.011      -0.002
# MSZoning             -0.0125      0.008     -1.607      0.108      -0.028       0.003
# LotFrontage          -0.0233      0.021     -1.126      0.260      -0.064       0.017
# LotArea               0.0823      0.015      5.521      0.000       0.053       0.112
# Street                0.0426      0.073      0.585      0.558      -0.100       0.186
# LotShape             -0.0286      0.019     -1.526      0.127      -0.065       0.008
# LandContour           0.0007      0.007      0.110      0.912      -0.013       0.014
# LotConfig            -0.0030      0.003     -1.138      0.255      -0.008       0.002
# LandSlope             0.0199      0.019      1.051      0.294      -0.017       0.057
# Neighborhood          0.0015      0.001      2.055      0.040    6.95e-05       0.003
# BldgType              0.0104      0.008      1.278      0.201      -0.006       0.026
# HouseStyle            0.0013      0.003      0.385      0.700      -0.005       0.008
# OverallCond           0.0502      0.005     10.259      0.000       0.041       0.060
# YearBuilt             0.0029      0.000      7.438      0.000       0.002       0.004
# RoofStyle             0.0091      0.005      1.723      0.085      -0.001       0.019
# RoofMatl              0.0127      0.008      1.659      0.097      -0.002       0.028
# MasVnrType            0.0158      0.008      1.996      0.046       0.000       0.031
# ExterCond            -0.0132      0.013     -1.038      0.300      -0.038       0.012
# Foundation            0.0213      0.008      2.646      0.008       0.006       0.037
# BsmtCond             -0.0094      0.015     -0.623      0.533      -0.039       0.020
# BsmtExposure          0.0230      0.005      4.583      0.000       0.013       0.033
# BsmtFinType1          0.0012      0.004      0.339      0.734      -0.006       0.008
# BsmtFinSF1         1.449e-05   3.11e-05      0.466      0.641   -4.65e-05    7.54e-05
# BsmtFinType2          0.0014      0.006      0.243      0.808      -0.010       0.012
# BsmtFinSF2        -4.103e-06   4.56e-05     -0.090      0.928   -9.36e-05    8.54e-05
# BsmtUnfSF         -1.775e-05   3.04e-05     -0.583      0.560   -7.75e-05     4.2e-05
# Heating               0.0018      0.014      0.127      0.899      -0.026       0.030
# HeatingQC             0.0126      0.006      2.261      0.024       0.002       0.024
# CentralAir            0.0297      0.021      1.403      0.161      -0.012       0.071
# Electrical           -0.0047      0.005     -1.050      0.294      -0.014       0.004
# 1stFlrSF          -4.696e-05   4.85e-05     -0.968      0.333      -0.000    4.82e-05
# 2ndFlrSF          -9.144e-05   3.94e-05     -2.320      0.021      -0.000   -1.41e-05
# LowQualFinSF      -6.599e-07   9.65e-05     -0.007      0.995      -0.000       0.000
# GrLivArea             0.5767      0.061      9.453      0.000       0.457       0.696
# BedroomAbvGr         -0.0098      0.008     -1.218      0.224      -0.026       0.006
# KitchenAbvGr         -0.0592      0.024     -2.423      0.016      -0.107      -0.011
# TotRmsAbvGrd          0.0092      0.006      1.604      0.109      -0.002       0.021
# Functional            0.0297      0.005      6.520      0.000       0.021       0.039
# Fireplaces           -0.0246      0.010     -2.414      0.016      -0.045      -0.005
# GarageType           -0.0036      0.009     -0.396      0.692      -0.022       0.014
# GarageYrBlt          -0.0004      0.000     -1.079      0.281      -0.001       0.000
# GarageFinish          0.0063      0.007      0.876      0.381      -0.008       0.021
# GarageArea            0.0795      0.017      4.621      0.000       0.046       0.113
# GarageCond            0.0018      0.019      0.096      0.923      -0.035       0.039
# PavedDrive            0.0086      0.010      0.863      0.388      -0.011       0.028
# WoodDeckSF           5.2e-05   3.56e-05      1.462      0.144   -1.78e-05       0.000
# OpenPorchSF       -3.174e-05   6.56e-05     -0.484      0.629      -0.000     9.7e-05
# EnclosedPorch         0.0001   7.52e-05      1.439      0.151   -3.94e-05       0.000
# 3SsnPorch             0.0001      0.000      0.855      0.393      -0.000       0.000
# PoolArea           8.021e-05      0.000      0.375      0.708      -0.000       0.000
# PoolQC               -0.0518      0.045     -1.148      0.251      -0.140       0.037
# Fence                 0.0022      0.004      0.598      0.550      -0.005       0.009
# MiscFeature          -0.0082      0.011     -0.739      0.460      -0.030       0.014
# MiscVal            2.265e-06   7.55e-06      0.300      0.764   -1.25e-05    1.71e-05
# MoSold               -0.0008      0.002     -0.549      0.583      -0.004       0.002
# YrSold               -0.0032      0.003     -1.002      0.317      -0.009       0.003
# SaleType              0.0004      0.003      0.151      0.880      -0.005       0.006
# SaleCondition         0.0162      0.004      3.937      0.000       0.008       0.024
# NewLotShape           0.0857      0.056      1.536      0.125      -0.024       0.195
# NewCondition1        -0.0011      0.016     -0.068      0.945      -0.032       0.030
# CountCon             -0.0640      0.041     -1.561      0.119      -0.144       0.016
# SameExterior         -0.0211      0.012     -1.756      0.079      -0.045       0.002
# New_Year_feature     -0.0157      0.009     -1.807      0.071      -0.033       0.001
# BsmtBath_counts       0.0434      0.011      3.854      0.000       0.021       0.066
# Bath_counts           0.0220      0.010      2.114      0.035       0.002       0.042
# Garage_in            -0.0254      0.039     -0.659      0.510      -0.101       0.050
# Garage_exist          0.2377      0.650      0.366      0.715      -1.038       1.514
# MasVnrArea_exist      0.0086      0.011      0.763      0.446      -0.014       0.031
# ScreenPorch_exist     0.0428      0.015      2.779      0.006       0.013       0.073
# BsmtArea              0.0217      0.009      2.317      0.021       0.003       0.040
# quality               0.1711      0.015     11.244      0.000       0.141       0.201
# ==============================================================================
# Omnibus:                      517.125   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10344.797
# Skew:                          -1.548   Prob(JB):                         0.00
# Kurtosis:                      17.247   Cond. No.                     5.98e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.98e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# const                3.044375e-01
# MSSubClass           6.388018e-03
# MSZoning             1.083978e-01
# LotFrontage          2.604915e-01
# LotArea              4.217455e-08
#                          ...
# Garage_exist         7.148063e-01
# MasVnrArea_exist     4.458513e-01
# ScreenPorch_exist    5.546037e-03
# BsmtArea             2.071361e-02
# quality              7.729578e-28
# Length: 72, dtype: float64

# %%
RMSE = mean_squared_error(y_pred, y_test)**0.5
print(RMSE)
# Out:
# 0.14498327033121763

# %%
data_feature=pd.DataFrame(results.pvalues)
data_feature=data_feature.rename(columns = {0:'feature'})

# %%
a = []
for i,j in zip(data_feature.index, data_feature['feature']):
    if j > 0.05:
        pass
    else:
        if i != 'const':
            a.append(i)

# %%
data_feature=train.loc[:,a]

# %%
data_feature.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'Neighborhood', 'OverallCond', 'YearBuilt',
#        'MasVnrType', 'Foundation', 'BsmtExposure', 'HeatingQC', '2ndFlrSF',
#        'GrLivArea', 'KitchenAbvGr', 'Functional', 'Fireplaces', 'GarageArea',
#        'SaleCondition', 'BsmtBath_counts', 'Bath_counts', 'ScreenPorch_exist',
#        'BsmtArea', 'quality'],
#       dtype='object')

# %%
X_train, X_test, y_train,y_test = train_test_split(data_feature,target, test_size = 0.2, random_state = 42)
lr=LinearRegression()
lr.fit(X_train, y_train)
y_pred=lr.predict(X_test)

RMSE=mean_squared_error(y_pred, y_test)**0.5
print(RMSE)
# Out:
# 0.14948291245803522

# %% [markdown]
# ## 두개의 변수로 찾아보기

# %%
data_feature=pd.concat([data_feature,target], axis = 1)

# %%
plt.figure(figsize = (16,8))
sns.distplot(data_feature['SalePrice'])
plt.title('SalePrice distribution')
# Out:
# Text(0.5, 1.0, 'SalePrice distribution')

# %% [markdown]
# - 우리는 종속변수인 SalePrice의 데이터를 평균에 맞춰준다.

# %%
data_feature.isnull().sum()
# Out:
# MSSubClass           0
# LotArea              0
# Neighborhood         0
# OverallCond          0
# YearBuilt            0
# MasVnrType           0
# Foundation           0
# BsmtExposure         0
# HeatingQC            0
# 2ndFlrSF             0
# GrLivArea            0
# KitchenAbvGr         0
# Functional           0
# Fireplaces           0
# GarageArea           0
# SaleCondition        0
# BsmtBath_counts      0
# Bath_counts          0
# ScreenPorch_exist    0
# BsmtArea             0
# quality              0
# SalePrice            0
# dtype: int64

# %% [markdown]
# ## Pycaret

# %%
# from pycaret.regression import *

# %%
# clf = setup(data_feature, target = 'SalePrice')

# %%
# best = compare_models(n_select = 3)

# %% [markdown]
# ## 두개의 변수로 찾아보기

# %%
data_feature.columns
data_feature['New_Year_feature'] = train['New_Year_feature']

# %%
plt.figure(figsize = (24,12))
data_feature_corr=data_feature.corr()
sns.heatmap(data_feature_corr, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 다중공산성 확인해보기

# %%
import statsmodels.api as sm

X = sm.add_constant(data_feature.drop('SalePrice', axis = 1))
y = data_feature['SalePrice']

model = sm.OLS(y,X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     468.3
# Date:                Mon, 10 May 2021   Prob (F-statistic):               0.00
# Time:                        22:12:23   Log-Likelihood:                 801.97
# No. Observations:                1460   AIC:                            -1558.
# Df Residuals:                    1437   BIC:                            -1436.
# Df Model:                          22
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.0880      0.591     -0.149      0.882      -1.248       1.072
# MSSubClass           -0.0033      0.001     -2.638      0.008      -0.006      -0.001
# LotArea               0.0756      0.010      7.737      0.000       0.056       0.095
# Neighborhood          0.0019      0.001      2.965      0.003       0.001       0.003
# OverallCond           0.0489      0.004     12.365      0.000       0.041       0.057
# YearBuilt             0.0030      0.000     10.924      0.000       0.003       0.004
# MasVnrType            0.0079      0.006      1.257      0.209      -0.004       0.020
# Foundation            0.0205      0.007      2.805      0.005       0.006       0.035
# BsmtExposure          0.0250      0.004      5.910      0.000       0.017       0.033
# HeatingQC             0.0150      0.005      3.149      0.002       0.006       0.024
# 2ndFlrSF          -8.159e-05   1.57e-05     -5.202      0.000      -0.000   -5.08e-05
# GrLivArea             0.5580      0.024     22.944      0.000       0.510       0.606
# KitchenAbvGr         -0.0578      0.021     -2.784      0.005      -0.099      -0.017
# Functional            0.0234      0.004      5.803      0.000       0.015       0.031
# Fireplaces           -0.0314      0.009     -3.599      0.000      -0.049      -0.014
# GarageArea            0.0013      0.003      0.432      0.666      -0.005       0.007
# SaleCondition         0.0210      0.004      6.012      0.000       0.014       0.028
# BsmtBath_counts       0.0599      0.008      7.699      0.000       0.045       0.075
# Bath_counts           0.0269      0.009      2.881      0.004       0.009       0.045
# ScreenPorch_exist     0.0477      0.014      3.391      0.001       0.020       0.075
# BsmtArea              0.0182      0.003      5.405      0.000       0.012       0.025
# quality               0.1919      0.013     14.818      0.000       0.167       0.217
# New_Year_feature     -0.0079      0.008     -1.032      0.302      -0.023       0.007
# ==============================================================================
# Omnibus:                      688.060   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14056.084
# Skew:                          -1.704   Prob(JB):                         0.00
# Kurtosis:                      17.814   Cond. No.                     3.22e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.22e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(data_feature.drop('SalePrice', axis = 1).values, i) for i in range(data_feature.drop('SalePrice',axis = 1).shape[1])]
vif['features'] = data_feature.drop('SalePrice',axis =1).columns
vif
# Out:
#      VIF Factor           features
# 0      3.888791         MSSubClass
# 1    578.371871            LotArea
# 2      5.654632       Neighborhood
# 3     30.689074        OverallCond
# 4   1485.607121          YearBuilt
# 5     10.021365         MasVnrType
# 6      8.491308         Foundation
# 7      4.925149       BsmtExposure
# 8     29.729818          HeatingQC
# 9      5.615789           2ndFlrSF
# 10  1872.146911          GrLivArea
# 11    36.318555       KitchenAbvGr
# 12    40.638322         Functional
# 13     4.365299         Fireplaces
# 14    25.638262         GarageArea
# 15    13.904593      SaleCondition
# 16     2.317664    BsmtBath_counts
# 17    21.898376        Bath_counts
# 18     1.152686  ScreenPorch_exist
# 19    53.982163           BsmtArea
# 20   110.937758            quality
# 21     5.204211   New_Year_feature

# %%
X_train, X_test, y_train,y_test = train_test_split(data_feature.drop('SalePrice',axis = 1),target, test_size = 0.2, random_state = 42)
lr=LinearRegression()
lr.fit(X_train, y_train)
y_pred=lr.predict(X_test)

RMSE=mean_squared_error(y_pred, y_test)**0.5
print(RMSE)
# Out:
# 0.14950561175348384

# %%
# xgbregressor
X_train, X_test, y_train,y_test = train_test_split(data_feature.drop('SalePrice',axis = 1),target, test_size = 0.2, random_state = 42)
xgb=XGBRegressor(random_state = 42, gamma = 0.0008, booster = 'dart')
xgb.fit(X_train, y_train)
y_pred=xgb.predict(X_test)

RMSE = mean_squared_error(y_pred, y_test)**0.5
print(RMSE)
# Out:
# 0.14262280894205484

# %%
# Randomforestregressor
rfg=RandomForestRegressor(random_state = 42, n_estimators = 150, max_depth = 20)
rfg.fit(X_train, y_train)
y_pred=rfg.predict(X_test)
RMSE = mean_squared_error(y_pred, y_test) **0.5
print(RMSE)
# Out:
# 0.1438472969251835

# %%
data_feature.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'Neighborhood', 'OverallCond', 'YearBuilt',
#        'MasVnrType', 'Foundation', 'BsmtExposure', 'HeatingQC', '2ndFlrSF',
#        'GrLivArea', 'KitchenAbvGr', 'Functional', 'Fireplaces', 'GarageArea',
#        'SaleCondition', 'BsmtBath_counts', 'Bath_counts', 'ScreenPorch_exist',
#        'BsmtArea', 'quality', 'SalePrice', 'New_Year_feature'],
#       dtype='object')

# %%
sns.scatterplot(data = data_feature, x = 'LotArea', y = 'SalePrice')
plt.title('LotArea vs SalePrice')
# Out:
# Text(0.5, 1.0, 'LotArea vs SalePrice')

# %%
data_feature['MSSubClass'].value_counts()
# Out:
# 0     536
# 5     299
# 4     144
# 11     87
# 1      69
# 12     63
# 6      60
# 8      58
# 10     52
# 14     30
# 9      20
# 7      16
# 3      12
# 13     10
# 2       4
# Name: MSSubClass, dtype: int64

# %%
sns.barplot(data = data_feature, x = 'MSSubClass', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='SalePrice'>

# %%
sns.scatterplot(data = data_feature, x = 'YearBuilt', y = 'SalePrice', hue = 'Foundation')
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %%
# YearBuilt를 Foundation을 기준으로 잘라준다.
data_feature.loc[data_feature['YearBuilt'] <= 1940,'Year_Foundation']  = 0
data_feature.loc[(data_feature['YearBuilt'] >= 1940) &(data_feature['YearBuilt'] < 1990), 'Year_Foundation'] = 1
data_feature.loc[(data_feature['YearBuilt'] >= 1990) , 'Year_Foundation'] = 2
data_feature=data_feature.drop('Foundation', axis = 1)

# %%
sns.barplot(data = data_feature, x = 'Year_Foundation', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='Year_Foundation', ylabel='SalePrice'>

# %%
data_feature.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'Neighborhood', 'OverallCond', 'YearBuilt',
#        'MasVnrType', 'BsmtExposure', 'HeatingQC', '2ndFlrSF', 'GrLivArea',
#        'KitchenAbvGr', 'Functional', 'Fireplaces', 'GarageArea',
#        'SaleCondition', 'BsmtBath_counts', 'Bath_counts', 'ScreenPorch_exist',
#        'BsmtArea', 'quality', 'SalePrice', 'New_Year_feature',
#        'Year_Foundation'],
#       dtype='object')

# %%
# Randomforestregressor
rfg=RandomForestRegressor(random_state = 42)
rfg.fit(X_train, y_train)
y_pred=rfg.predict(X_test)

RMSE = mean_squared_error(y_pred, y_test) **0.5
print(RMSE)
# Out:
# 0.14466662523432636

# %%
data_feature.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'Neighborhood', 'OverallCond', 'YearBuilt',
#        'MasVnrType', 'BsmtExposure', 'HeatingQC', '2ndFlrSF', 'GrLivArea',
#        'KitchenAbvGr', 'Functional', 'Fireplaces', 'GarageArea',
#        'SaleCondition', 'BsmtBath_counts', 'Bath_counts', 'ScreenPorch_exist',
#        'BsmtArea', 'quality', 'SalePrice', 'New_Year_feature',
#        'Year_Foundation'],
#       dtype='object')

# %% [markdown]
# ## SaleCondition

# %%
sns.boxenplot(data = data_feature, x = 'SaleCondition', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='SalePrice'>

# %% [markdown]
# - SaleCondition은 딱히 건드리고 싶지 않다.

# %% [markdown]
# ## 2ndFlrSF

# %%
# 0에 몰려있는 데이터가 많기 때문에 2층이 있으면 1 없으면 0으로 바꿔준다.
sns.scatterplot(data = data_feature, x = '2ndFlrSF',y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='2ndFlrSF', ylabel='SalePrice'>

# %%
data_feature['2_floor_exist'] = data_feature['2ndFlrSF'].apply(lambda x:1 if x >0  else 0)

# %%
# 1과 0 사이에 차이가 있다.
sns.boxenplot(data = data_feature, x = '2_floor_exist', y = 'SalePrice')

data_feature = data_feature.drop('2ndFlrSF', axis = 1)

# %%
data_feature.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'Neighborhood', 'OverallCond', 'YearBuilt',
#        'MasVnrType', 'BsmtExposure', 'HeatingQC', 'GrLivArea', 'KitchenAbvGr',
#        'Functional', 'Fireplaces', 'GarageArea', 'SaleCondition',
#        'BsmtBath_counts', 'Bath_counts', 'ScreenPorch_exist', 'BsmtArea',
#        'quality', 'SalePrice', 'New_Year_feature', 'Year_Foundation',
#        '2_floor_exist'],
#       dtype='object')

# %% [markdown]
# ## KitchenAbvGr

# %%
sns.boxenplot(data = data_feature, x = 'KitchenAbvGr', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='KitchenAbvGr', ylabel='SalePrice'>

# %%
data_feature=data_feature.drop('KitchenAbvGr', axis = 1)

# %%
data_feature.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'Neighborhood', 'OverallCond', 'YearBuilt',
#        'MasVnrType', 'BsmtExposure', 'HeatingQC', 'GrLivArea', 'Functional',
#        'Fireplaces', 'GarageArea', 'SaleCondition', 'BsmtBath_counts',
#        'Bath_counts', 'ScreenPorch_exist', 'BsmtArea', 'quality', 'SalePrice',
#        'New_Year_feature', 'Year_Foundation', '2_floor_exist'],
#       dtype='object')

# %%
# xgbregressor
X_train, X_test, y_train,y_test = train_test_split(data_feature.drop('SalePrice',axis = 1),target, test_size = 0.2, random_state = 41)
xgb=XGBRegressor(random_state = 6, gamma = 0.0005, booster = 'dart')
xgb.fit(X_train, y_train)
y_pred=xgb.predict(X_test)

RMSE = mean_squared_error(y_pred, y_test)**0.5
print(RMSE)
# Out:
# 0.1275020754004101

# %% [markdown]
# ## Stacking ensemble을 사용한 모델링

# %%
from sklearn.linear_model import Ridge,Lasso,HuberRegressor,LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor

models={'lgb':LinearRegression(),'Ridge':Ridge(),'Lasso':Lasso(),'xgb':XGBRegressor(),'rgb':RandomForestRegressor(), 'cat':CatBoostRegressor()}
def good_models(models, data = None, target = None):
    X_train, X_test, y_train, y_test = train_test_split(data, target, test_size = 0.2, random_state = 42)
    model_rmse = {}
    for model in models:
        models[model].fit(X_train, y_train)
        y_pred=models[model].predict(X_test)
        model_rmse[model] = y_pred
    
    return model_rmse

# %%
best_model=good_models(models = models,data = data_feature.drop('SalePrice', axis = 1), 
            target = data_feature['SalePrice'])
# Out:
# Learning rate set to 0.040124
# 0:	learn: 0.3802421	total: 141ms	remaining: 2m 20s
# 1:	learn: 0.3706049	total: 144ms	remaining: 1m 11s
# 2:	learn: 0.3605844	total: 145ms	remaining: 48.2s
# 3:	learn: 0.3517252	total: 147ms	remaining: 36.5s
# 4:	learn: 0.3423227	total: 148ms	remaining: 29.5s
# 5:	learn: 0.3347897	total: 150ms	remaining: 24.9s
# 6:	learn: 0.3265288	total: 152ms	remaining: 21.5s
# 7:	learn: 0.3188681	total: 154ms	remaining: 19.1s
# 8:	learn: 0.3114818	total: 156ms	remaining: 17.1s
# 9:	learn: 0.3041873	total: 157ms	remaining: 15.6s
# 10:	learn: 0.2967410	total: 159ms	remaining: 14.3s
# 11:	learn: 0.2901873	total: 161ms	remaining: 13.2s
# 12:	learn: 0.2839053	total: 163ms	remaining: 12.4s
# 13:	learn: 0.2785883	total: 165ms	remaining: 11.6s
# 14:	learn: 0.2726522	total: 166ms	remaining: 10.9s
# 15:	learn: 0.2670214	total: 168ms	remaining: 10.3s
# 16:	learn: 0.2615697	total: 170ms	remaining: 9.84s
# 17:	learn: 0.2564014	total: 172ms	remaining: 9.38s
# 18:	learn: 0.2512588	total: 174ms	remaining: 8.99s
# 19:	learn: 0.2463650	total: 176ms	remaining: 8.63s
# 20:	learn: 0.2419445	total: 179ms	remaining: 8.34s
# 21:	learn: 0.2373733	total: 181ms	remaining: 8.04s
# 22:	learn: 0.2332286	total: 183ms	remaining: 7.76s
# 23:	learn: 0.2292429	total: 185ms	remaining: 7.51s
# 24:	learn: 0.2253822	total: 187ms	remaining: 7.27s
# 25:	learn: 0.2214114	total: 188ms	remaining: 7.06s
# 26:	learn: 0.2178964	total: 190ms	remaining: 6.86s
# 27:	learn: 0.2145969	total: 193ms	remaining: 6.68s
# 28:	learn: 0.2114593	total: 195ms	remaining: 6.53s
# 29:	learn: 0.2088422	total: 199ms	remaining: 6.45s
# 30:	learn: 0.2055349	total: 202ms	remaining: 6.31s
# 31:	learn: 0.2026808	total: 204ms	remaining: 6.16s
# 32:	learn: 0.1994572	total: 209ms	remaining: 6.13s
# 33:	learn: 0.1967878	total: 211ms	remaining: 6.01s
# 34:	learn: 0.1939286	total: 214ms	remaining: 5.9s
# 35:	learn: 0.1916967	total: 216ms	remaining: 5.8s
# 36:	learn: 0.1892132	total: 218ms	remaining: 5.68s
# 37:	learn: 0.1865984	total: 220ms	remaining: 5.57s
# 38:	learn: 0.1840453	total: 222ms	remaining: 5.46s
# 39:	learn: 0.1817465	total: 223ms	remaining: 5.36s
# 40:	learn: 0.1797597	total: 225ms	remaining: 5.27s
# 41:	learn: 0.1777214	total: 227ms	remaining: 5.18s
# 42:	learn: 0.1756623	total: 229ms	remaining: 5.1s
# 43:	learn: 0.1739405	total: 231ms	remaining: 5.03s
# 44:	learn: 0.1720451	total: 233ms	remaining: 4.95s
# 45:	learn: 0.1701656	total: 235ms	remaining: 4.88s
# 46:	learn: 0.1684268	total: 237ms	remaining: 4.8s
# 47:	learn: 0.1667930	total: 239ms	remaining: 4.73s
# 48:	learn: 0.1653152	total: 240ms	remaining: 4.67s
# 49:	learn: 0.1639958	total: 242ms	remaining: 4.6s
# 50:	learn: 0.1626494	total: 244ms	remaining: 4.54s
# 51:	learn: 0.1610290	total: 246ms	remaining: 4.48s
# 52:	learn: 0.1594792	total: 248ms	remaining: 4.42s
# 53:	learn: 0.1581948	total: 249ms	remaining: 4.37s
# 54:	learn: 0.1568406	total: 251ms	remaining: 4.32s
# 55:	learn: 0.1556613	total: 253ms	remaining: 4.26s
# 56:	learn: 0.1543171	total: 255ms	remaining: 4.21s
# 57:	learn: 0.1532355	total: 256ms	remaining: 4.16s
# 58:	learn: 0.1520582	total: 258ms	remaining: 4.12s
# 59:	learn: 0.1509603	total: 260ms	remaining: 4.08s
# 60:	learn: 0.1497972	total: 262ms	remaining: 4.03s
# 61:	learn: 0.1484643	total: 264ms	remaining: 3.99s
# 62:	learn: 0.1473336	total: 266ms	remaining: 3.95s
# 63:	learn: 0.1464455	total: 267ms	remaining: 3.91s
# 64:	learn: 0.1455003	total: 269ms	remaining: 3.87s
# 65:	learn: 0.1445854	total: 271ms	remaining: 3.83s
# 66:	learn: 0.1436651	total: 272ms	remaining: 3.79s
# 67:	learn: 0.1427872	total: 274ms	remaining: 3.76s
# 68:	learn: 0.1418983	total: 276ms	remaining: 3.72s
# 69:	learn: 0.1410076	total: 278ms	remaining: 3.69s
# 70:	learn: 0.1401008	total: 280ms	remaining: 3.66s
# 71:	learn: 0.1392786	total: 281ms	remaining: 3.63s
# 72:	learn: 0.1385103	total: 283ms	remaining: 3.6s
# 73:	learn: 0.1376120	total: 285ms	remaining: 3.56s
# 74:	learn: 0.1368378	total: 287ms	remaining: 3.54s
# 75:	learn: 0.1360867	total: 288ms	remaining: 3.51s
# 76:	learn: 0.1355163	total: 290ms	remaining: 3.48s
# 77:	learn: 0.1349442	total: 292ms	remaining: 3.45s
# 78:	learn: 0.1342939	total: 294ms	remaining: 3.43s
# 79:	learn: 0.1334998	total: 296ms	remaining: 3.41s
# 80:	learn: 0.1328330	total: 298ms	remaining: 3.38s
# 81:	learn: 0.1320065	total: 300ms	remaining: 3.36s
# 82:	learn: 0.1312833	total: 302ms	remaining: 3.33s
# 83:	learn: 0.1307281	total: 303ms	remaining: 3.31s
# 84:	learn: 0.1302561	total: 305ms	remaining: 3.28s
# 85:	learn: 0.1294353	total: 307ms	remaining: 3.26s
# 86:	learn: 0.1288332	total: 309ms	remaining: 3.24s
# 87:	learn: 0.1283110	total: 311ms	remaining: 3.22s
# 88:	learn: 0.1277643	total: 312ms	remaining: 3.2s
# 89:	learn: 0.1271661	total: 314ms	remaining: 3.18s
# 90:	learn: 0.1267523	total: 316ms	remaining: 3.15s
# 91:	learn: 0.1260789	total: 318ms	remaining: 3.13s
# 92:	learn: 0.1255084	total: 319ms	remaining: 3.11s
# 93:	learn: 0.1250154	total: 321ms	remaining: 3.1s
# 94:	learn: 0.1245391	total: 323ms	remaining: 3.08s
# 95:	learn: 0.1240310	total: 325ms	remaining: 3.06s
# 96:	learn: 0.1236202	total: 327ms	remaining: 3.04s
# 97:	learn: 0.1230947	total: 328ms	remaining: 3.02s
# 98:	learn: 0.1226963	total: 330ms	remaining: 3s
# 99:	learn: 0.1222544	total: 332ms	remaining: 2.99s
# 100:	learn: 0.1218434	total: 334ms	remaining: 2.97s
# 101:	learn: 0.1214572	total: 335ms	remaining: 2.95s
# 102:	learn: 0.1210631	total: 337ms	remaining: 2.94s
# 103:	learn: 0.1206309	total: 339ms	remaining: 2.92s
# 104:	learn: 0.1202866	total: 341ms	remaining: 2.91s
# 105:	learn: 0.1199011	total: 343ms	remaining: 2.89s
# 106:	learn: 0.1195721	total: 345ms	remaining: 2.88s
# 107:	learn: 0.1192290	total: 348ms	remaining: 2.87s
# 108:	learn: 0.1189507	total: 349ms	remaining: 2.86s
# 109:	learn: 0.1186879	total: 352ms	remaining: 2.85s
# 110:	learn: 0.1183438	total: 355ms	remaining: 2.84s
# 111:	learn: 0.1179551	total: 357ms	remaining: 2.83s
# 112:	learn: 0.1175959	total: 358ms	remaining: 2.81s
# 113:	learn: 0.1173574	total: 360ms	remaining: 2.8s
# 114:	learn: 0.1170511	total: 362ms	remaining: 2.79s
# 115:	learn: 0.1166884	total: 364ms	remaining: 2.78s
# 116:	learn: 0.1163962	total: 366ms	remaining: 2.76s
# 117:	learn: 0.1160820	total: 369ms	remaining: 2.75s
# 118:	learn: 0.1157131	total: 371ms	remaining: 2.75s
# 119:	learn: 0.1153461	total: 374ms	remaining: 2.74s
# 120:	learn: 0.1149413	total: 375ms	remaining: 2.73s
# 121:	learn: 0.1147395	total: 377ms	remaining: 2.71s
# 122:	learn: 0.1144881	total: 379ms	remaining: 2.71s
# 123:	learn: 0.1142187	total: 382ms	remaining: 2.69s
# 124:	learn: 0.1138744	total: 386ms	remaining: 2.7s
# 125:	learn: 0.1136338	total: 387ms	remaining: 2.69s
# 126:	learn: 0.1134370	total: 389ms	remaining: 2.67s
# 127:	learn: 0.1131189	total: 391ms	remaining: 2.66s
# 128:	learn: 0.1128220	total: 393ms	remaining: 2.65s
# 129:	learn: 0.1126313	total: 395ms	remaining: 2.64s
# 130:	learn: 0.1123811	total: 397ms	remaining: 2.63s
# 131:	learn: 0.1120136	total: 399ms	remaining: 2.62s
# 132:	learn: 0.1117265	total: 401ms	remaining: 2.61s
# 133:	learn: 0.1114726	total: 403ms	remaining: 2.6s
# 134:	learn: 0.1112214	total: 404ms	remaining: 2.59s
# 135:	learn: 0.1109821	total: 406ms	remaining: 2.58s
# 136:	learn: 0.1107352	total: 408ms	remaining: 2.57s
# 137:	learn: 0.1104792	total: 410ms	remaining: 2.56s
# 138:	learn: 0.1102475	total: 412ms	remaining: 2.55s
# 139:	learn: 0.1099966	total: 414ms	remaining: 2.54s
# 140:	learn: 0.1096690	total: 416ms	remaining: 2.53s
# 141:	learn: 0.1093559	total: 418ms	remaining: 2.52s
# 142:	learn: 0.1091510	total: 420ms	remaining: 2.52s
# 143:	learn: 0.1089036	total: 422ms	remaining: 2.51s
# 144:	learn: 0.1086032	total: 424ms	remaining: 2.5s
# 145:	learn: 0.1083474	total: 427ms	remaining: 2.5s
# 146:	learn: 0.1080951	total: 429ms	remaining: 2.49s
# 147:	learn: 0.1078447	total: 431ms	remaining: 2.48s
# 148:	learn: 0.1076219	total: 433ms	remaining: 2.47s
# 149:	learn: 0.1073778	total: 435ms	remaining: 2.46s
# 150:	learn: 0.1071052	total: 436ms	remaining: 2.45s
# 151:	learn: 0.1069124	total: 438ms	remaining: 2.44s
# 152:	learn: 0.1067131	total: 440ms	remaining: 2.44s
# 153:	learn: 0.1064615	total: 442ms	remaining: 2.43s
# 154:	learn: 0.1062224	total: 444ms	remaining: 2.42s
# 155:	learn: 0.1059267	total: 446ms	remaining: 2.41s
# 156:	learn: 0.1057641	total: 447ms	remaining: 2.4s
# 157:	learn: 0.1055278	total: 449ms	remaining: 2.39s
# 158:	learn: 0.1052004	total: 451ms	remaining: 2.39s
# 159:	learn: 0.1049975	total: 453ms	remaining: 2.38s
# 160:	learn: 0.1047864	total: 455ms	remaining: 2.37s
# 161:	learn: 0.1046396	total: 457ms	remaining: 2.36s
# 162:	learn: 0.1044656	total: 458ms	remaining: 2.35s
# 163:	learn: 0.1042858	total: 460ms	remaining: 2.35s
# 164:	learn: 0.1040471	total: 462ms	remaining: 2.34s
# 165:	learn: 0.1038551	total: 464ms	remaining: 2.33s
# 166:	learn: 0.1036478	total: 466ms	remaining: 2.32s
# 167:	learn: 0.1034916	total: 467ms	remaining: 2.31s
# 168:	learn: 0.1033067	total: 469ms	remaining: 2.31s
# 169:	learn: 0.1030863	total: 471ms	remaining: 2.3s
# 170:	learn: 0.1028649	total: 472ms	remaining: 2.29s
# 171:	learn: 0.1026296	total: 474ms	remaining: 2.28s
# 172:	learn: 0.1023821	total: 476ms	remaining: 2.27s
# 173:	learn: 0.1021994	total: 478ms	remaining: 2.27s
# 174:	learn: 0.1020172	total: 480ms	remaining: 2.26s
# 175:	learn: 0.1018383	total: 482ms	remaining: 2.25s
# 176:	learn: 0.1016257	total: 483ms	remaining: 2.25s
# 177:	learn: 0.1014113	total: 485ms	remaining: 2.24s
# 178:	learn: 0.1011670	total: 487ms	remaining: 2.23s
# 179:	learn: 0.1010235	total: 489ms	remaining: 2.23s
# 180:	learn: 0.1009043	total: 490ms	remaining: 2.22s
# 181:	learn: 0.1007746	total: 492ms	remaining: 2.21s
# 182:	learn: 0.1006438	total: 494ms	remaining: 2.21s
# 183:	learn: 0.1004629	total: 496ms	remaining: 2.2s
# 184:	learn: 0.1001983	total: 498ms	remaining: 2.19s
# 185:	learn: 0.1000989	total: 499ms	remaining: 2.19s
# 186:	learn: 0.0998442	total: 501ms	remaining: 2.18s
# 187:	learn: 0.0996841	total: 503ms	remaining: 2.17s
# 188:	learn: 0.0994651	total: 505ms	remaining: 2.17s
# 189:	learn: 0.0992797	total: 507ms	remaining: 2.16s
# 190:	learn: 0.0990952	total: 508ms	remaining: 2.15s
# 191:	learn: 0.0988671	total: 510ms	remaining: 2.15s
# 192:	learn: 0.0987913	total: 512ms	remaining: 2.14s
# 193:	learn: 0.0986829	total: 514ms	remaining: 2.13s
# 194:	learn: 0.0985359	total: 515ms	remaining: 2.13s
# 195:	learn: 0.0982751	total: 517ms	remaining: 2.12s
# 196:	learn: 0.0981146	total: 520ms	remaining: 2.12s
# 197:	learn: 0.0979145	total: 522ms	remaining: 2.11s
# 198:	learn: 0.0977889	total: 524ms	remaining: 2.11s
# 199:	learn: 0.0976021	total: 526ms	remaining: 2.1s
# 200:	learn: 0.0974806	total: 528ms	remaining: 2.1s
# 201:	learn: 0.0973304	total: 529ms	remaining: 2.09s
# 202:	learn: 0.0971916	total: 531ms	remaining: 2.09s
# 203:	learn: 0.0970418	total: 533ms	remaining: 2.08s
# 204:	learn: 0.0969232	total: 535ms	remaining: 2.08s
# 205:	learn: 0.0966515	total: 537ms	remaining: 2.07s
# 206:	learn: 0.0964782	total: 540ms	remaining: 2.07s
# 207:	learn: 0.0964132	total: 542ms	remaining: 2.06s
# 208:	learn: 0.0963069	total: 543ms	remaining: 2.06s
# 209:	learn: 0.0960430	total: 546ms	remaining: 2.05s
# 210:	learn: 0.0958991	total: 547ms	remaining: 2.05s
# 211:	learn: 0.0956542	total: 549ms	remaining: 2.04s
# 212:	learn: 0.0955712	total: 551ms	remaining: 2.04s
# 213:	learn: 0.0954646	total: 553ms	remaining: 2.03s
# 214:	learn: 0.0953722	total: 555ms	remaining: 2.02s
# 215:	learn: 0.0952448	total: 556ms	remaining: 2.02s
# 216:	learn: 0.0951833	total: 558ms	remaining: 2.01s
# 217:	learn: 0.0950318	total: 560ms	remaining: 2.01s
# 218:	learn: 0.0949524	total: 562ms	remaining: 2s
# 219:	learn: 0.0948322	total: 563ms	remaining: 2s
# 220:	learn: 0.0946054	total: 565ms	remaining: 1.99s
# 221:	learn: 0.0944185	total: 567ms	remaining: 1.99s
# 222:	learn: 0.0942467	total: 569ms	remaining: 1.98s
# 223:	learn: 0.0940370	total: 570ms	remaining: 1.98s
# 224:	learn: 0.0939659	total: 572ms	remaining: 1.97s
# 225:	learn: 0.0937964	total: 574ms	remaining: 1.96s
# 226:	learn: 0.0937067	total: 575ms	remaining: 1.96s
# 227:	learn: 0.0935307	total: 577ms	remaining: 1.95s
# 228:	learn: 0.0933419	total: 579ms	remaining: 1.95s
# 229:	learn: 0.0932645	total: 580ms	remaining: 1.94s
# 230:	learn: 0.0931354	total: 582ms	remaining: 1.94s
# 231:	learn: 0.0930778	total: 584ms	remaining: 1.93s
# 232:	learn: 0.0929628	total: 586ms	remaining: 1.93s
# 233:	learn: 0.0929134	total: 587ms	remaining: 1.92s
# 234:	learn: 0.0928128	total: 589ms	remaining: 1.92s
# 235:	learn: 0.0926469	total: 591ms	remaining: 1.91s
# 236:	learn: 0.0924367	total: 593ms	remaining: 1.91s
# 237:	learn: 0.0923488	total: 594ms	remaining: 1.9s
# 238:	learn: 0.0921809	total: 596ms	remaining: 1.9s
# 239:	learn: 0.0920106	total: 599ms	remaining: 1.9s
# 240:	learn: 0.0919038	total: 601ms	remaining: 1.89s
# 241:	learn: 0.0918497	total: 603ms	remaining: 1.89s
# 242:	learn: 0.0917494	total: 604ms	remaining: 1.88s
# 243:	learn: 0.0914510	total: 606ms	remaining: 1.88s
# 244:	learn: 0.0913407	total: 608ms	remaining: 1.87s
# 245:	learn: 0.0912385	total: 610ms	remaining: 1.87s
# 246:	learn: 0.0909918	total: 612ms	remaining: 1.87s
# 247:	learn: 0.0907787	total: 614ms	remaining: 1.86s
# 248:	learn: 0.0906945	total: 616ms	remaining: 1.86s
# 249:	learn: 0.0905276	total: 618ms	remaining: 1.85s
# 250:	learn: 0.0902900	total: 619ms	remaining: 1.85s
# 251:	learn: 0.0902363	total: 621ms	remaining: 1.84s
# 252:	learn: 0.0900957	total: 623ms	remaining: 1.84s
# 253:	learn: 0.0900386	total: 625ms	remaining: 1.83s
# 254:	learn: 0.0899424	total: 626ms	remaining: 1.83s
# 255:	learn: 0.0898692	total: 628ms	remaining: 1.82s
# 256:	learn: 0.0897396	total: 630ms	remaining: 1.82s
# 257:	learn: 0.0896061	total: 632ms	remaining: 1.82s
# 258:	learn: 0.0894946	total: 634ms	remaining: 1.81s
# 259:	learn: 0.0893956	total: 635ms	remaining: 1.81s
# 260:	learn: 0.0891720	total: 637ms	remaining: 1.8s
# 261:	learn: 0.0891290	total: 639ms	remaining: 1.8s
# 262:	learn: 0.0890732	total: 641ms	remaining: 1.8s
# 263:	learn: 0.0888721	total: 643ms	remaining: 1.79s
# 264:	learn: 0.0886869	total: 644ms	remaining: 1.79s
# 265:	learn: 0.0885486	total: 646ms	remaining: 1.78s
# 266:	learn: 0.0884891	total: 648ms	remaining: 1.78s
# 267:	learn: 0.0883639	total: 650ms	remaining: 1.77s
# 268:	learn: 0.0882148	total: 652ms	remaining: 1.77s
# 269:	learn: 0.0881358	total: 653ms	remaining: 1.77s
# 270:	learn: 0.0879678	total: 655ms	remaining: 1.76s
# 271:	learn: 0.0877752	total: 657ms	remaining: 1.76s
# 272:	learn: 0.0876700	total: 659ms	remaining: 1.75s
# 273:	learn: 0.0875865	total: 661ms	remaining: 1.75s
# 274:	learn: 0.0875001	total: 663ms	remaining: 1.75s
# 275:	learn: 0.0873726	total: 664ms	remaining: 1.74s
# 276:	learn: 0.0872056	total: 666ms	remaining: 1.74s
# 277:	learn: 0.0870151	total: 668ms	remaining: 1.73s
# 278:	learn: 0.0868101	total: 670ms	remaining: 1.73s
# 279:	learn: 0.0866842	total: 672ms	remaining: 1.73s
# 280:	learn: 0.0865178	total: 674ms	remaining: 1.72s
# 281:	learn: 0.0864764	total: 675ms	remaining: 1.72s
# 282:	learn: 0.0863978	total: 677ms	remaining: 1.72s
# 283:	learn: 0.0862826	total: 679ms	remaining: 1.71s
# 284:	learn: 0.0860874	total: 681ms	remaining: 1.71s
# 285:	learn: 0.0859169	total: 682ms	remaining: 1.7s
# 286:	learn: 0.0858059	total: 685ms	remaining: 1.7s
# 287:	learn: 0.0856862	total: 686ms	remaining: 1.7s
# 288:	learn: 0.0856611	total: 689ms	remaining: 1.69s
# 289:	learn: 0.0855001	total: 691ms	remaining: 1.69s
# 290:	learn: 0.0853347	total: 694ms	remaining: 1.69s
# 291:	learn: 0.0852456	total: 695ms	remaining: 1.69s
# 292:	learn: 0.0851354	total: 697ms	remaining: 1.68s
# 293:	learn: 0.0850497	total: 699ms	remaining: 1.68s
# 294:	learn: 0.0849337	total: 701ms	remaining: 1.68s
# 295:	learn: 0.0848307	total: 704ms	remaining: 1.67s
# 296:	learn: 0.0846823	total: 706ms	remaining: 1.67s
# 297:	learn: 0.0845976	total: 708ms	remaining: 1.67s
# 298:	learn: 0.0844380	total: 710ms	remaining: 1.66s
# 299:	learn: 0.0844016	total: 712ms	remaining: 1.66s
# 300:	learn: 0.0843056	total: 714ms	remaining: 1.66s
# 301:	learn: 0.0840758	total: 715ms	remaining: 1.65s
# 302:	learn: 0.0839645	total: 717ms	remaining: 1.65s
# 303:	learn: 0.0837926	total: 719ms	remaining: 1.65s
# 304:	learn: 0.0836662	total: 721ms	remaining: 1.64s
# 305:	learn: 0.0835332	total: 723ms	remaining: 1.64s
# 306:	learn: 0.0834763	total: 725ms	remaining: 1.64s
# 307:	learn: 0.0833711	total: 726ms	remaining: 1.63s
# 308:	learn: 0.0832273	total: 728ms	remaining: 1.63s
# 309:	learn: 0.0831077	total: 730ms	remaining: 1.62s
# 310:	learn: 0.0829822	total: 732ms	remaining: 1.62s
# 311:	learn: 0.0828011	total: 734ms	remaining: 1.62s
# 312:	learn: 0.0827107	total: 736ms	remaining: 1.61s
# 313:	learn: 0.0825949	total: 737ms	remaining: 1.61s
# 314:	learn: 0.0825147	total: 739ms	remaining: 1.61s
# 315:	learn: 0.0823633	total: 741ms	remaining: 1.6s
# 316:	learn: 0.0822650	total: 743ms	remaining: 1.6s
# 317:	learn: 0.0821636	total: 744ms	remaining: 1.6s
# 318:	learn: 0.0821115	total: 746ms	remaining: 1.59s
# 319:	learn: 0.0819690	total: 748ms	remaining: 1.59s
# 320:	learn: 0.0818015	total: 750ms	remaining: 1.59s
# 321:	learn: 0.0817386	total: 752ms	remaining: 1.58s
# 322:	learn: 0.0816558	total: 753ms	remaining: 1.58s
# 323:	learn: 0.0815455	total: 755ms	remaining: 1.57s
# 324:	learn: 0.0814145	total: 757ms	remaining: 1.57s
# 325:	learn: 0.0812303	total: 759ms	remaining: 1.57s
# 326:	learn: 0.0811001	total: 760ms	remaining: 1.56s
# 327:	learn: 0.0810801	total: 762ms	remaining: 1.56s
# 328:	learn: 0.0809117	total: 764ms	remaining: 1.56s
# 329:	learn: 0.0808008	total: 767ms	remaining: 1.56s
# 330:	learn: 0.0807103	total: 769ms	remaining: 1.55s
# 331:	learn: 0.0806405	total: 771ms	remaining: 1.55s
# 332:	learn: 0.0805760	total: 773ms	remaining: 1.55s
# 333:	learn: 0.0804970	total: 774ms	remaining: 1.54s
# 334:	learn: 0.0803830	total: 776ms	remaining: 1.54s
# 335:	learn: 0.0802911	total: 779ms	remaining: 1.54s
# 336:	learn: 0.0800876	total: 782ms	remaining: 1.54s
# 337:	learn: 0.0799702	total: 784ms	remaining: 1.53s
# 338:	learn: 0.0798403	total: 786ms	remaining: 1.53s
# 339:	learn: 0.0797200	total: 788ms	remaining: 1.53s
# 340:	learn: 0.0796384	total: 789ms	remaining: 1.52s
# 341:	learn: 0.0795273	total: 791ms	remaining: 1.52s
# 342:	learn: 0.0793715	total: 794ms	remaining: 1.52s
# 343:	learn: 0.0792851	total: 798ms	remaining: 1.52s
# 344:	learn: 0.0792207	total: 800ms	remaining: 1.52s
# 345:	learn: 0.0790667	total: 802ms	remaining: 1.51s
# 346:	learn: 0.0789820	total: 803ms	remaining: 1.51s
# 347:	learn: 0.0788401	total: 805ms	remaining: 1.51s
# 348:	learn: 0.0787173	total: 807ms	remaining: 1.5s
# 349:	learn: 0.0785693	total: 810ms	remaining: 1.5s
# 350:	learn: 0.0785296	total: 813ms	remaining: 1.5s
# 351:	learn: 0.0783997	total: 815ms	remaining: 1.5s
# 352:	learn: 0.0783637	total: 817ms	remaining: 1.5s
# 353:	learn: 0.0782597	total: 819ms	remaining: 1.49s
# 354:	learn: 0.0781795	total: 821ms	remaining: 1.49s
# 355:	learn: 0.0780939	total: 823ms	remaining: 1.49s
# 356:	learn: 0.0779436	total: 826ms	remaining: 1.49s
# 357:	learn: 0.0778651	total: 829ms	remaining: 1.49s
# 358:	learn: 0.0777706	total: 831ms	remaining: 1.48s
# 359:	learn: 0.0776363	total: 833ms	remaining: 1.48s
# 360:	learn: 0.0775155	total: 835ms	remaining: 1.48s
# 361:	learn: 0.0773617	total: 837ms	remaining: 1.47s
# 362:	learn: 0.0772393	total: 839ms	remaining: 1.47s
# 363:	learn: 0.0771763	total: 843ms	remaining: 1.47s
# 364:	learn: 0.0770447	total: 845ms	remaining: 1.47s
# 365:	learn: 0.0769367	total: 847ms	remaining: 1.47s
# 366:	learn: 0.0768201	total: 848ms	remaining: 1.46s
# 367:	learn: 0.0767266	total: 850ms	remaining: 1.46s
# 368:	learn: 0.0766370	total: 852ms	remaining: 1.46s
# 369:	learn: 0.0765996	total: 855ms	remaining: 1.46s
# 370:	learn: 0.0764452	total: 859ms	remaining: 1.46s
# 371:	learn: 0.0763242	total: 861ms	remaining: 1.45s
# 372:	learn: 0.0762503	total: 863ms	remaining: 1.45s
# 373:	learn: 0.0760751	total: 865ms	remaining: 1.45s
# 374:	learn: 0.0759867	total: 867ms	remaining: 1.45s
# 375:	learn: 0.0758962	total: 871ms	remaining: 1.45s
# 376:	learn: 0.0757624	total: 874ms	remaining: 1.44s
# 377:	learn: 0.0756938	total: 876ms	remaining: 1.44s
# 378:	learn: 0.0755953	total: 878ms	remaining: 1.44s
# 379:	learn: 0.0755028	total: 881ms	remaining: 1.44s
# 380:	learn: 0.0754671	total: 883ms	remaining: 1.44s
# 381:	learn: 0.0753515	total: 888ms	remaining: 1.44s
# 382:	learn: 0.0752707	total: 899ms	remaining: 1.45s
# 383:	learn: 0.0751492	total: 902ms	remaining: 1.45s
# 384:	learn: 0.0750528	total: 905ms	remaining: 1.45s
# 385:	learn: 0.0748983	total: 907ms	remaining: 1.44s
# 386:	learn: 0.0748181	total: 909ms	remaining: 1.44s
# 387:	learn: 0.0747309	total: 911ms	remaining: 1.44s
# 388:	learn: 0.0745758	total: 912ms	remaining: 1.43s
# 389:	learn: 0.0744790	total: 914ms	remaining: 1.43s
# 390:	learn: 0.0743666	total: 918ms	remaining: 1.43s
# 391:	learn: 0.0741846	total: 921ms	remaining: 1.43s
# 392:	learn: 0.0741191	total: 923ms	remaining: 1.43s
# 393:	learn: 0.0740099	total: 925ms	remaining: 1.42s
# 394:	learn: 0.0739443	total: 927ms	remaining: 1.42s
# 395:	learn: 0.0737984	total: 928ms	remaining: 1.42s
# 396:	learn: 0.0737197	total: 930ms	remaining: 1.41s
# 397:	learn: 0.0736513	total: 933ms	remaining: 1.41s
# 398:	learn: 0.0736378	total: 936ms	remaining: 1.41s
# 399:	learn: 0.0735518	total: 937ms	remaining: 1.41s
# 400:	learn: 0.0734523	total: 939ms	remaining: 1.4s
# 401:	learn: 0.0733817	total: 941ms	remaining: 1.4s
# 402:	learn: 0.0733053	total: 943ms	remaining: 1.4s
# 403:	learn: 0.0732494	total: 945ms	remaining: 1.39s
# 404:	learn: 0.0731578	total: 948ms	remaining: 1.39s
# 405:	learn: 0.0730553	total: 950ms	remaining: 1.39s
# 406:	learn: 0.0728848	total: 952ms	remaining: 1.39s
# 407:	learn: 0.0727454	total: 954ms	remaining: 1.38s
# 408:	learn: 0.0726425	total: 956ms	remaining: 1.38s
# 409:	learn: 0.0725626	total: 958ms	remaining: 1.38s
# 410:	learn: 0.0724319	total: 960ms	remaining: 1.38s
# 411:	learn: 0.0723770	total: 962ms	remaining: 1.37s
# 412:	learn: 0.0722832	total: 965ms	remaining: 1.37s
# 413:	learn: 0.0722343	total: 966ms	remaining: 1.37s
# 414:	learn: 0.0721726	total: 968ms	remaining: 1.36s
# 415:	learn: 0.0721126	total: 970ms	remaining: 1.36s
# 416:	learn: 0.0720435	total: 972ms	remaining: 1.36s
# 417:	learn: 0.0719562	total: 974ms	remaining: 1.35s
# 418:	learn: 0.0719206	total: 975ms	remaining: 1.35s
# 419:	learn: 0.0718387	total: 978ms	remaining: 1.35s
# 420:	learn: 0.0717701	total: 981ms	remaining: 1.35s
# 421:	learn: 0.0716854	total: 983ms	remaining: 1.35s
# 422:	learn: 0.0715621	total: 985ms	remaining: 1.34s
# 423:	learn: 0.0714826	total: 987ms	remaining: 1.34s
# 424:	learn: 0.0713925	total: 988ms	remaining: 1.34s
# 425:	learn: 0.0713007	total: 990ms	remaining: 1.33s
# 426:	learn: 0.0711759	total: 993ms	remaining: 1.33s
# 427:	learn: 0.0710891	total: 995ms	remaining: 1.33s
# 428:	learn: 0.0710266	total: 996ms	remaining: 1.33s
# 429:	learn: 0.0709423	total: 998ms	remaining: 1.32s
# 430:	learn: 0.0708408	total: 1000ms	remaining: 1.32s
# 431:	learn: 0.0707700	total: 1s	remaining: 1.32s
# 432:	learn: 0.0706613	total: 1s	remaining: 1.31s
# 433:	learn: 0.0705906	total: 1s	remaining: 1.31s
# 434:	learn: 0.0704884	total: 1.01s	remaining: 1.31s
# 435:	learn: 0.0704378	total: 1.01s	remaining: 1.3s
# 436:	learn: 0.0703486	total: 1.01s	remaining: 1.3s
# 437:	learn: 0.0702871	total: 1.01s	remaining: 1.3s
# 438:	learn: 0.0702200	total: 1.01s	remaining: 1.29s
# 439:	learn: 0.0701820	total: 1.01s	remaining: 1.29s
# 440:	learn: 0.0701340	total: 1.02s	remaining: 1.29s
# 441:	learn: 0.0700163	total: 1.02s	remaining: 1.29s
# 442:	learn: 0.0699849	total: 1.02s	remaining: 1.28s
# 443:	learn: 0.0699667	total: 1.02s	remaining: 1.28s
# 444:	learn: 0.0698391	total: 1.02s	remaining: 1.28s
# 445:	learn: 0.0697218	total: 1.03s	remaining: 1.27s
# 446:	learn: 0.0696657	total: 1.03s	remaining: 1.27s
# 447:	learn: 0.0695540	total: 1.03s	remaining: 1.27s
# 448:	learn: 0.0694430	total: 1.03s	remaining: 1.27s
# 449:	learn: 0.0693390	total: 1.03s	remaining: 1.26s
# 450:	learn: 0.0692167	total: 1.04s	remaining: 1.26s
# 451:	learn: 0.0691241	total: 1.04s	remaining: 1.26s
# 452:	learn: 0.0690729	total: 1.04s	remaining: 1.26s
# 453:	learn: 0.0689872	total: 1.05s	remaining: 1.26s
# 454:	learn: 0.0688868	total: 1.05s	remaining: 1.25s
# 455:	learn: 0.0688501	total: 1.05s	remaining: 1.25s
# 456:	learn: 0.0687688	total: 1.05s	remaining: 1.25s
# 457:	learn: 0.0686555	total: 1.05s	remaining: 1.25s
# 458:	learn: 0.0685850	total: 1.06s	remaining: 1.24s
# 459:	learn: 0.0685415	total: 1.06s	remaining: 1.24s
# 460:	learn: 0.0684327	total: 1.06s	remaining: 1.24s
# 461:	learn: 0.0683413	total: 1.06s	remaining: 1.24s
# 462:	learn: 0.0682806	total: 1.06s	remaining: 1.23s
# 463:	learn: 0.0682049	total: 1.06s	remaining: 1.23s
# 464:	learn: 0.0680742	total: 1.07s	remaining: 1.23s
# 465:	learn: 0.0680104	total: 1.07s	remaining: 1.22s
# 466:	learn: 0.0679056	total: 1.07s	remaining: 1.22s
# 467:	learn: 0.0678264	total: 1.07s	remaining: 1.22s
# 468:	learn: 0.0677303	total: 1.07s	remaining: 1.22s
# 469:	learn: 0.0675971	total: 1.08s	remaining: 1.21s
# 470:	learn: 0.0674987	total: 1.08s	remaining: 1.21s
# 471:	learn: 0.0674394	total: 1.08s	remaining: 1.21s
# 472:	learn: 0.0673513	total: 1.08s	remaining: 1.2s
# 473:	learn: 0.0672453	total: 1.08s	remaining: 1.2s
# 474:	learn: 0.0671732	total: 1.08s	remaining: 1.2s
# 475:	learn: 0.0670748	total: 1.09s	remaining: 1.2s
# 476:	learn: 0.0669901	total: 1.09s	remaining: 1.19s
# 477:	learn: 0.0669790	total: 1.09s	remaining: 1.19s
# 478:	learn: 0.0668686	total: 1.09s	remaining: 1.19s
# 479:	learn: 0.0667824	total: 1.09s	remaining: 1.18s
# 480:	learn: 0.0666615	total: 1.09s	remaining: 1.18s
# 481:	learn: 0.0665643	total: 1.1s	remaining: 1.18s
# 482:	learn: 0.0665174	total: 1.1s	remaining: 1.18s
# 483:	learn: 0.0664520	total: 1.1s	remaining: 1.17s
# 484:	learn: 0.0663729	total: 1.1s	remaining: 1.17s
# 485:	learn: 0.0662875	total: 1.1s	remaining: 1.17s
# 486:	learn: 0.0662637	total: 1.11s	remaining: 1.17s
# 487:	learn: 0.0661933	total: 1.11s	remaining: 1.16s
# 488:	learn: 0.0661403	total: 1.11s	remaining: 1.16s
# 489:	learn: 0.0660496	total: 1.11s	remaining: 1.16s
# 490:	learn: 0.0659798	total: 1.11s	remaining: 1.15s
# 491:	learn: 0.0659486	total: 1.11s	remaining: 1.15s
# 492:	learn: 0.0659046	total: 1.12s	remaining: 1.15s
# 493:	learn: 0.0658098	total: 1.12s	remaining: 1.15s
# 494:	learn: 0.0657870	total: 1.12s	remaining: 1.14s
# 495:	learn: 0.0657102	total: 1.12s	remaining: 1.14s
# 496:	learn: 0.0655993	total: 1.12s	remaining: 1.14s
# 497:	learn: 0.0654877	total: 1.13s	remaining: 1.14s
# 498:	learn: 0.0654004	total: 1.13s	remaining: 1.13s
# 499:	learn: 0.0653617	total: 1.13s	remaining: 1.13s
# 500:	learn: 0.0653257	total: 1.13s	remaining: 1.13s
# 501:	learn: 0.0652241	total: 1.13s	remaining: 1.12s
# 502:	learn: 0.0651665	total: 1.14s	remaining: 1.12s
# 503:	learn: 0.0650949	total: 1.14s	remaining: 1.12s
# 504:	learn: 0.0650186	total: 1.14s	remaining: 1.12s
# 505:	learn: 0.0649421	total: 1.14s	remaining: 1.11s
# 506:	learn: 0.0648864	total: 1.14s	remaining: 1.11s
# 507:	learn: 0.0647745	total: 1.15s	remaining: 1.11s
# 508:	learn: 0.0646931	total: 1.15s	remaining: 1.11s
# 509:	learn: 0.0646294	total: 1.15s	remaining: 1.1s
# 510:	learn: 0.0645537	total: 1.15s	remaining: 1.1s
# 511:	learn: 0.0645232	total: 1.15s	remaining: 1.1s
# 512:	learn: 0.0644580	total: 1.15s	remaining: 1.09s
# 513:	learn: 0.0643878	total: 1.16s	remaining: 1.09s
# 514:	learn: 0.0643400	total: 1.16s	remaining: 1.09s
# 515:	learn: 0.0642592	total: 1.16s	remaining: 1.09s
# 516:	learn: 0.0641959	total: 1.16s	remaining: 1.08s
# 517:	learn: 0.0641021	total: 1.16s	remaining: 1.08s
# 518:	learn: 0.0640463	total: 1.17s	remaining: 1.08s
# 519:	learn: 0.0639647	total: 1.17s	remaining: 1.08s
# 520:	learn: 0.0638792	total: 1.17s	remaining: 1.07s
# 521:	learn: 0.0637842	total: 1.17s	remaining: 1.07s
# 522:	learn: 0.0637099	total: 1.17s	remaining: 1.07s
# 523:	learn: 0.0636292	total: 1.17s	remaining: 1.07s
# 524:	learn: 0.0635748	total: 1.18s	remaining: 1.06s
# 525:	learn: 0.0634788	total: 1.18s	remaining: 1.06s
# 526:	learn: 0.0634464	total: 1.18s	remaining: 1.06s
# 527:	learn: 0.0634052	total: 1.18s	remaining: 1.05s
# 528:	learn: 0.0633235	total: 1.18s	remaining: 1.05s
# 529:	learn: 0.0632575	total: 1.18s	remaining: 1.05s
# 530:	learn: 0.0632084	total: 1.19s	remaining: 1.05s
# 531:	learn: 0.0631611	total: 1.19s	remaining: 1.04s
# 532:	learn: 0.0630955	total: 1.19s	remaining: 1.04s
# 533:	learn: 0.0630780	total: 1.19s	remaining: 1.04s
# 534:	learn: 0.0629696	total: 1.19s	remaining: 1.04s
# 535:	learn: 0.0629126	total: 1.2s	remaining: 1.03s
# 536:	learn: 0.0628649	total: 1.2s	remaining: 1.03s
# 537:	learn: 0.0627833	total: 1.2s	remaining: 1.03s
# 538:	learn: 0.0627609	total: 1.2s	remaining: 1.03s
# 539:	learn: 0.0627083	total: 1.2s	remaining: 1.02s
# 540:	learn: 0.0626036	total: 1.21s	remaining: 1.02s
# 541:	learn: 0.0625157	total: 1.21s	remaining: 1.02s
# 542:	learn: 0.0624450	total: 1.21s	remaining: 1.02s
# 543:	learn: 0.0623287	total: 1.21s	remaining: 1.01s
# 544:	learn: 0.0622780	total: 1.21s	remaining: 1.01s
# 545:	learn: 0.0622060	total: 1.22s	remaining: 1.01s
# 546:	learn: 0.0621391	total: 1.22s	remaining: 1.01s
# 547:	learn: 0.0620163	total: 1.22s	remaining: 1.01s
# 548:	learn: 0.0619596	total: 1.22s	remaining: 1s
# 549:	learn: 0.0618634	total: 1.22s	remaining: 1s
# 550:	learn: 0.0618278	total: 1.23s	remaining: 999ms
# 551:	learn: 0.0617886	total: 1.23s	remaining: 996ms
# 552:	learn: 0.0617164	total: 1.23s	remaining: 994ms
# 553:	learn: 0.0615938	total: 1.23s	remaining: 992ms
# 554:	learn: 0.0614696	total: 1.23s	remaining: 989ms
# 555:	learn: 0.0614295	total: 1.24s	remaining: 986ms
# 556:	learn: 0.0613691	total: 1.24s	remaining: 984ms
# 557:	learn: 0.0612669	total: 1.24s	remaining: 982ms
# 558:	learn: 0.0611819	total: 1.24s	remaining: 979ms
# 559:	learn: 0.0610998	total: 1.24s	remaining: 977ms
# 560:	learn: 0.0610574	total: 1.24s	remaining: 974ms
# 561:	learn: 0.0609687	total: 1.25s	remaining: 972ms
# 562:	learn: 0.0609353	total: 1.25s	remaining: 969ms
# 563:	learn: 0.0609105	total: 1.25s	remaining: 966ms
# 564:	learn: 0.0608393	total: 1.25s	remaining: 964ms
# 565:	learn: 0.0607600	total: 1.25s	remaining: 962ms
# 566:	learn: 0.0607398	total: 1.25s	remaining: 959ms
# 567:	learn: 0.0606717	total: 1.26s	remaining: 956ms
# 568:	learn: 0.0606545	total: 1.26s	remaining: 954ms
# 569:	learn: 0.0605762	total: 1.26s	remaining: 952ms
# 570:	learn: 0.0605382	total: 1.26s	remaining: 949ms
# 571:	learn: 0.0604969	total: 1.26s	remaining: 946ms
# 572:	learn: 0.0604442	total: 1.27s	remaining: 944ms
# 573:	learn: 0.0603725	total: 1.27s	remaining: 941ms
# 574:	learn: 0.0603130	total: 1.27s	remaining: 939ms
# 575:	learn: 0.0602576	total: 1.27s	remaining: 936ms
# 576:	learn: 0.0601979	total: 1.27s	remaining: 934ms
# 577:	learn: 0.0601659	total: 1.27s	remaining: 931ms
# 578:	learn: 0.0600908	total: 1.28s	remaining: 929ms
# 579:	learn: 0.0600516	total: 1.28s	remaining: 926ms
# 580:	learn: 0.0600033	total: 1.28s	remaining: 924ms
# 581:	learn: 0.0599175	total: 1.28s	remaining: 921ms
# 582:	learn: 0.0598916	total: 1.28s	remaining: 919ms
# 583:	learn: 0.0598139	total: 1.29s	remaining: 916ms
# 584:	learn: 0.0597224	total: 1.29s	remaining: 914ms
# 585:	learn: 0.0596577	total: 1.29s	remaining: 912ms
# 586:	learn: 0.0595829	total: 1.29s	remaining: 909ms
# 587:	learn: 0.0594964	total: 1.29s	remaining: 906ms
# 588:	learn: 0.0594374	total: 1.29s	remaining: 904ms
# 589:	learn: 0.0593857	total: 1.3s	remaining: 906ms
# 590:	learn: 0.0593438	total: 1.31s	remaining: 904ms
# 591:	learn: 0.0592909	total: 1.31s	remaining: 901ms
# 592:	learn: 0.0592077	total: 1.31s	remaining: 899ms
# 593:	learn: 0.0591818	total: 1.31s	remaining: 896ms
# 594:	learn: 0.0591485	total: 1.31s	remaining: 894ms
# 595:	learn: 0.0590745	total: 1.31s	remaining: 891ms
# 596:	learn: 0.0590362	total: 1.32s	remaining: 889ms
# 597:	learn: 0.0589913	total: 1.32s	remaining: 886ms
# 598:	learn: 0.0589331	total: 1.32s	remaining: 884ms
# 599:	learn: 0.0588697	total: 1.32s	remaining: 881ms
# 600:	learn: 0.0588217	total: 1.32s	remaining: 879ms
# 601:	learn: 0.0587132	total: 1.32s	remaining: 876ms
# 602:	learn: 0.0586570	total: 1.33s	remaining: 874ms
# 603:	learn: 0.0585858	total: 1.33s	remaining: 871ms
# 604:	learn: 0.0585426	total: 1.33s	remaining: 869ms
# 605:	learn: 0.0585114	total: 1.33s	remaining: 867ms
# 606:	learn: 0.0584593	total: 1.33s	remaining: 864ms
# 607:	learn: 0.0584184	total: 1.34s	remaining: 862ms
# 608:	learn: 0.0583948	total: 1.34s	remaining: 859ms
# 609:	learn: 0.0583477	total: 1.34s	remaining: 857ms
# 610:	learn: 0.0582660	total: 1.34s	remaining: 854ms
# 611:	learn: 0.0582227	total: 1.34s	remaining: 852ms
# 612:	learn: 0.0581296	total: 1.34s	remaining: 849ms
# 613:	learn: 0.0580792	total: 1.35s	remaining: 847ms
# 614:	learn: 0.0580185	total: 1.35s	remaining: 845ms
# 615:	learn: 0.0579958	total: 1.35s	remaining: 842ms
# 616:	learn: 0.0579521	total: 1.35s	remaining: 840ms
# 617:	learn: 0.0578980	total: 1.35s	remaining: 837ms
# 618:	learn: 0.0578507	total: 1.36s	remaining: 835ms
# 619:	learn: 0.0577604	total: 1.36s	remaining: 832ms
# 620:	learn: 0.0576955	total: 1.36s	remaining: 830ms
# 621:	learn: 0.0576466	total: 1.36s	remaining: 828ms
# 622:	learn: 0.0575624	total: 1.36s	remaining: 825ms
# 623:	learn: 0.0574895	total: 1.36s	remaining: 823ms
# 624:	learn: 0.0574536	total: 1.37s	remaining: 820ms
# 625:	learn: 0.0573788	total: 1.37s	remaining: 818ms
# 626:	learn: 0.0573032	total: 1.37s	remaining: 815ms
# 627:	learn: 0.0572688	total: 1.37s	remaining: 813ms
# 628:	learn: 0.0572402	total: 1.38s	remaining: 811ms
# 629:	learn: 0.0571596	total: 1.38s	remaining: 809ms
# 630:	learn: 0.0571244	total: 1.38s	remaining: 807ms
# 631:	learn: 0.0570811	total: 1.38s	remaining: 804ms
# 632:	learn: 0.0570193	total: 1.38s	remaining: 802ms
# 633:	learn: 0.0569696	total: 1.39s	remaining: 800ms
# 634:	learn: 0.0569281	total: 1.39s	remaining: 798ms
# 635:	learn: 0.0568373	total: 1.39s	remaining: 796ms
# 636:	learn: 0.0567712	total: 1.39s	remaining: 793ms
# 637:	learn: 0.0566948	total: 1.39s	remaining: 791ms
# 638:	learn: 0.0566356	total: 1.4s	remaining: 789ms
# 639:	learn: 0.0565711	total: 1.4s	remaining: 787ms
# 640:	learn: 0.0565409	total: 1.4s	remaining: 784ms
# 641:	learn: 0.0564776	total: 1.4s	remaining: 782ms
# 642:	learn: 0.0564607	total: 1.4s	remaining: 779ms
# 643:	learn: 0.0563858	total: 1.41s	remaining: 778ms
# 644:	learn: 0.0562976	total: 1.41s	remaining: 776ms
# 645:	learn: 0.0562545	total: 1.41s	remaining: 773ms
# 646:	learn: 0.0562203	total: 1.41s	remaining: 771ms
# 647:	learn: 0.0561869	total: 1.42s	remaining: 769ms
# 648:	learn: 0.0561295	total: 1.42s	remaining: 767ms
# 649:	learn: 0.0560678	total: 1.42s	remaining: 765ms
# 650:	learn: 0.0559688	total: 1.42s	remaining: 762ms
# 651:	learn: 0.0559350	total: 1.42s	remaining: 760ms
# 652:	learn: 0.0559051	total: 1.43s	remaining: 758ms
# 653:	learn: 0.0558715	total: 1.43s	remaining: 755ms
# 654:	learn: 0.0558475	total: 1.43s	remaining: 753ms
# 655:	learn: 0.0557805	total: 1.43s	remaining: 751ms
# 656:	learn: 0.0557410	total: 1.43s	remaining: 748ms
# 657:	learn: 0.0557115	total: 1.44s	remaining: 746ms
# 658:	learn: 0.0556606	total: 1.44s	remaining: 744ms
# 659:	learn: 0.0555902	total: 1.44s	remaining: 741ms
# 660:	learn: 0.0555089	total: 1.44s	remaining: 739ms
# 661:	learn: 0.0554521	total: 1.44s	remaining: 736ms
# 662:	learn: 0.0553846	total: 1.44s	remaining: 734ms
# 663:	learn: 0.0553226	total: 1.45s	remaining: 731ms
# 664:	learn: 0.0552486	total: 1.45s	remaining: 729ms
# 665:	learn: 0.0552158	total: 1.45s	remaining: 727ms
# 666:	learn: 0.0551819	total: 1.45s	remaining: 724ms
# 667:	learn: 0.0551640	total: 1.45s	remaining: 722ms
# 668:	learn: 0.0550905	total: 1.45s	remaining: 719ms
# 669:	learn: 0.0550407	total: 1.46s	remaining: 717ms
# 670:	learn: 0.0550119	total: 1.46s	remaining: 715ms
# 671:	learn: 0.0549503	total: 1.46s	remaining: 712ms
# 672:	learn: 0.0548839	total: 1.46s	remaining: 710ms
# 673:	learn: 0.0548473	total: 1.46s	remaining: 707ms
# 674:	learn: 0.0548092	total: 1.46s	remaining: 705ms
# 675:	learn: 0.0547772	total: 1.47s	remaining: 703ms
# 676:	learn: 0.0547458	total: 1.47s	remaining: 700ms
# 677:	learn: 0.0547146	total: 1.47s	remaining: 698ms
# 678:	learn: 0.0546427	total: 1.47s	remaining: 696ms
# 679:	learn: 0.0545543	total: 1.47s	remaining: 693ms
# 680:	learn: 0.0545120	total: 1.47s	remaining: 691ms
# 681:	learn: 0.0544286	total: 1.48s	remaining: 688ms
# 682:	learn: 0.0543891	total: 1.48s	remaining: 686ms
# 683:	learn: 0.0543297	total: 1.48s	remaining: 684ms
# 684:	learn: 0.0542613	total: 1.48s	remaining: 681ms
# 685:	learn: 0.0542056	total: 1.48s	remaining: 679ms
# 686:	learn: 0.0540995	total: 1.48s	remaining: 677ms
# 687:	learn: 0.0540419	total: 1.49s	remaining: 674ms
# 688:	learn: 0.0540080	total: 1.49s	remaining: 672ms
# 689:	learn: 0.0539566	total: 1.49s	remaining: 669ms
# 690:	learn: 0.0539451	total: 1.49s	remaining: 667ms
# 691:	learn: 0.0538774	total: 1.49s	remaining: 665ms
# 692:	learn: 0.0538393	total: 1.5s	remaining: 662ms
# 693:	learn: 0.0537682	total: 1.5s	remaining: 660ms
# 694:	learn: 0.0537206	total: 1.5s	remaining: 658ms
# 695:	learn: 0.0536604	total: 1.5s	remaining: 655ms
# 696:	learn: 0.0536122	total: 1.5s	remaining: 653ms
# 697:	learn: 0.0535473	total: 1.5s	remaining: 651ms
# 698:	learn: 0.0535030	total: 1.5s	remaining: 648ms
# 699:	learn: 0.0534470	total: 1.51s	remaining: 646ms
# 700:	learn: 0.0534034	total: 1.51s	remaining: 644ms
# 701:	learn: 0.0533393	total: 1.51s	remaining: 641ms
# 702:	learn: 0.0532991	total: 1.51s	remaining: 639ms
# 703:	learn: 0.0532443	total: 1.51s	remaining: 637ms
# 704:	learn: 0.0532091	total: 1.51s	remaining: 634ms
# 705:	learn: 0.0531951	total: 1.52s	remaining: 632ms
# 706:	learn: 0.0531770	total: 1.52s	remaining: 630ms
# 707:	learn: 0.0531328	total: 1.52s	remaining: 627ms
# 708:	learn: 0.0531113	total: 1.52s	remaining: 625ms
# 709:	learn: 0.0530507	total: 1.52s	remaining: 623ms
# 710:	learn: 0.0529929	total: 1.52s	remaining: 620ms
# 711:	learn: 0.0529306	total: 1.53s	remaining: 618ms
# 712:	learn: 0.0528824	total: 1.53s	remaining: 616ms
# 713:	learn: 0.0527947	total: 1.53s	remaining: 613ms
# 714:	learn: 0.0527458	total: 1.53s	remaining: 611ms
# 715:	learn: 0.0526982	total: 1.53s	remaining: 609ms
# 716:	learn: 0.0526743	total: 1.54s	remaining: 606ms
# 717:	learn: 0.0525994	total: 1.54s	remaining: 604ms
# 718:	learn: 0.0525571	total: 1.54s	remaining: 602ms
# 719:	learn: 0.0525039	total: 1.54s	remaining: 599ms
# 720:	learn: 0.0524153	total: 1.54s	remaining: 597ms
# 721:	learn: 0.0523799	total: 1.54s	remaining: 595ms
# 722:	learn: 0.0523765	total: 1.55s	remaining: 593ms
# 723:	learn: 0.0523100	total: 1.55s	remaining: 590ms
# 724:	learn: 0.0522362	total: 1.55s	remaining: 588ms
# 725:	learn: 0.0521979	total: 1.55s	remaining: 586ms
# 726:	learn: 0.0521238	total: 1.55s	remaining: 584ms
# 727:	learn: 0.0520865	total: 1.56s	remaining: 582ms
# 728:	learn: 0.0520156	total: 1.56s	remaining: 579ms
# 729:	learn: 0.0519680	total: 1.56s	remaining: 577ms
# 730:	learn: 0.0519016	total: 1.56s	remaining: 575ms
# 731:	learn: 0.0518419	total: 1.56s	remaining: 573ms
# 732:	learn: 0.0517872	total: 1.57s	remaining: 571ms
# 733:	learn: 0.0517415	total: 1.57s	remaining: 568ms
# 734:	learn: 0.0516565	total: 1.57s	remaining: 566ms
# 735:	learn: 0.0516072	total: 1.57s	remaining: 564ms
# 736:	learn: 0.0515717	total: 1.57s	remaining: 562ms
# 737:	learn: 0.0515231	total: 1.57s	remaining: 559ms
# 738:	learn: 0.0514923	total: 1.58s	remaining: 557ms
# 739:	learn: 0.0514682	total: 1.58s	remaining: 555ms
# 740:	learn: 0.0514201	total: 1.58s	remaining: 553ms
# 741:	learn: 0.0513840	total: 1.58s	remaining: 550ms
# 742:	learn: 0.0513401	total: 1.58s	remaining: 548ms
# 743:	learn: 0.0512911	total: 1.59s	remaining: 546ms
# 744:	learn: 0.0512662	total: 1.59s	remaining: 544ms
# 745:	learn: 0.0511962	total: 1.59s	remaining: 541ms
# 746:	learn: 0.0511685	total: 1.59s	remaining: 539ms
# 747:	learn: 0.0511243	total: 1.59s	remaining: 537ms
# 748:	learn: 0.0510805	total: 1.6s	remaining: 535ms
# 749:	learn: 0.0510327	total: 1.6s	remaining: 533ms
# 750:	learn: 0.0509754	total: 1.6s	remaining: 530ms
# 751:	learn: 0.0508869	total: 1.6s	remaining: 528ms
# 752:	learn: 0.0508218	total: 1.6s	remaining: 526ms
# 753:	learn: 0.0507846	total: 1.6s	remaining: 524ms
# 754:	learn: 0.0507358	total: 1.61s	remaining: 522ms
# 755:	learn: 0.0506919	total: 1.61s	remaining: 519ms
# 756:	learn: 0.0506399	total: 1.61s	remaining: 517ms
# 757:	learn: 0.0505824	total: 1.61s	remaining: 515ms
# 758:	learn: 0.0505284	total: 1.61s	remaining: 513ms
# 759:	learn: 0.0504683	total: 1.62s	remaining: 510ms
# 760:	learn: 0.0504139	total: 1.62s	remaining: 508ms
# 761:	learn: 0.0503540	total: 1.62s	remaining: 506ms
# 762:	learn: 0.0503365	total: 1.62s	remaining: 504ms
# 763:	learn: 0.0502682	total: 1.62s	remaining: 502ms
# 764:	learn: 0.0502087	total: 1.63s	remaining: 499ms
# 765:	learn: 0.0501875	total: 1.63s	remaining: 497ms
# 766:	learn: 0.0501581	total: 1.63s	remaining: 495ms
# 767:	learn: 0.0501093	total: 1.63s	remaining: 493ms
# 768:	learn: 0.0500932	total: 1.63s	remaining: 491ms
# 769:	learn: 0.0500598	total: 1.63s	remaining: 488ms
# 770:	learn: 0.0500124	total: 1.64s	remaining: 486ms
# 771:	learn: 0.0499582	total: 1.64s	remaining: 484ms
# 772:	learn: 0.0499212	total: 1.64s	remaining: 482ms
# 773:	learn: 0.0499077	total: 1.64s	remaining: 479ms
# 774:	learn: 0.0498483	total: 1.64s	remaining: 477ms
# 775:	learn: 0.0498073	total: 1.64s	remaining: 475ms
# 776:	learn: 0.0497718	total: 1.65s	remaining: 473ms
# 777:	learn: 0.0497171	total: 1.65s	remaining: 470ms
# 778:	learn: 0.0496739	total: 1.65s	remaining: 468ms
# 779:	learn: 0.0496336	total: 1.65s	remaining: 466ms
# 780:	learn: 0.0495933	total: 1.65s	remaining: 464ms
# 781:	learn: 0.0495644	total: 1.66s	remaining: 461ms
# 782:	learn: 0.0495198	total: 1.66s	remaining: 459ms
# 783:	learn: 0.0494632	total: 1.66s	remaining: 457ms
# 784:	learn: 0.0494202	total: 1.66s	remaining: 455ms
# 785:	learn: 0.0493993	total: 1.66s	remaining: 453ms
# 786:	learn: 0.0493682	total: 1.66s	remaining: 450ms
# 787:	learn: 0.0493390	total: 1.67s	remaining: 448ms
# 788:	learn: 0.0492943	total: 1.67s	remaining: 446ms
# 789:	learn: 0.0492553	total: 1.67s	remaining: 444ms
# 790:	learn: 0.0491986	total: 1.67s	remaining: 441ms
# 791:	learn: 0.0491467	total: 1.67s	remaining: 439ms
# 792:	learn: 0.0491051	total: 1.67s	remaining: 437ms
# 793:	learn: 0.0490575	total: 1.68s	remaining: 435ms
# 794:	learn: 0.0490090	total: 1.68s	remaining: 432ms
# 795:	learn: 0.0489922	total: 1.68s	remaining: 430ms
# 796:	learn: 0.0489539	total: 1.68s	remaining: 428ms
# 797:	learn: 0.0488967	total: 1.68s	remaining: 426ms
# 798:	learn: 0.0488687	total: 1.68s	remaining: 424ms
# 799:	learn: 0.0488431	total: 1.69s	remaining: 422ms
# 800:	learn: 0.0487917	total: 1.69s	remaining: 419ms
# 801:	learn: 0.0487004	total: 1.69s	remaining: 417ms
# 802:	learn: 0.0486647	total: 1.69s	remaining: 415ms
# 803:	learn: 0.0485941	total: 1.69s	remaining: 413ms
# 804:	learn: 0.0485496	total: 1.69s	remaining: 410ms
# 805:	learn: 0.0485173	total: 1.7s	remaining: 408ms
# 806:	learn: 0.0484871	total: 1.7s	remaining: 406ms
# 807:	learn: 0.0484468	total: 1.7s	remaining: 404ms
# 808:	learn: 0.0483808	total: 1.7s	remaining: 402ms
# 809:	learn: 0.0483396	total: 1.7s	remaining: 399ms
# 810:	learn: 0.0482949	total: 1.7s	remaining: 397ms
# 811:	learn: 0.0482633	total: 1.71s	remaining: 395ms
# 812:	learn: 0.0482128	total: 1.71s	remaining: 393ms
# 813:	learn: 0.0481786	total: 1.71s	remaining: 391ms
# 814:	learn: 0.0481553	total: 1.71s	remaining: 389ms
# 815:	learn: 0.0481141	total: 1.71s	remaining: 386ms
# 816:	learn: 0.0480732	total: 1.71s	remaining: 384ms
# 817:	learn: 0.0480241	total: 1.72s	remaining: 382ms
# 818:	learn: 0.0479623	total: 1.72s	remaining: 380ms
# 819:	learn: 0.0479235	total: 1.72s	remaining: 378ms
# 820:	learn: 0.0478793	total: 1.72s	remaining: 376ms
# 821:	learn: 0.0478146	total: 1.73s	remaining: 374ms
# 822:	learn: 0.0477895	total: 1.73s	remaining: 372ms
# 823:	learn: 0.0477624	total: 1.73s	remaining: 369ms
# 824:	learn: 0.0477064	total: 1.73s	remaining: 367ms
# 825:	learn: 0.0476728	total: 1.73s	remaining: 365ms
# 826:	learn: 0.0476209	total: 1.74s	remaining: 363ms
# 827:	learn: 0.0475771	total: 1.74s	remaining: 361ms
# 828:	learn: 0.0475497	total: 1.74s	remaining: 359ms
# 829:	learn: 0.0475172	total: 1.74s	remaining: 357ms
# 830:	learn: 0.0474864	total: 1.74s	remaining: 355ms
# 831:	learn: 0.0474482	total: 1.75s	remaining: 352ms
# 832:	learn: 0.0474164	total: 1.75s	remaining: 350ms
# 833:	learn: 0.0473747	total: 1.75s	remaining: 348ms
# 834:	learn: 0.0473356	total: 1.75s	remaining: 346ms
# 835:	learn: 0.0472944	total: 1.75s	remaining: 344ms
# 836:	learn: 0.0472336	total: 1.75s	remaining: 342ms
# 837:	learn: 0.0471801	total: 1.75s	remaining: 339ms
# 838:	learn: 0.0471285	total: 1.76s	remaining: 337ms
# 839:	learn: 0.0470825	total: 1.76s	remaining: 335ms
# 840:	learn: 0.0470599	total: 1.76s	remaining: 333ms
# 841:	learn: 0.0470285	total: 1.76s	remaining: 331ms
# 842:	learn: 0.0469855	total: 1.76s	remaining: 329ms
# 843:	learn: 0.0469491	total: 1.76s	remaining: 326ms
# 844:	learn: 0.0469143	total: 1.77s	remaining: 324ms
# 845:	learn: 0.0468687	total: 1.77s	remaining: 322ms
# 846:	learn: 0.0468126	total: 1.77s	remaining: 320ms
# 847:	learn: 0.0467723	total: 1.77s	remaining: 318ms
# 848:	learn: 0.0467556	total: 1.77s	remaining: 316ms
# 849:	learn: 0.0466884	total: 1.78s	remaining: 313ms
# 850:	learn: 0.0466691	total: 1.78s	remaining: 311ms
# 851:	learn: 0.0466226	total: 1.78s	remaining: 309ms
# 852:	learn: 0.0465972	total: 1.78s	remaining: 307ms
# 853:	learn: 0.0465669	total: 1.78s	remaining: 305ms
# 854:	learn: 0.0465186	total: 1.78s	remaining: 303ms
# 855:	learn: 0.0464809	total: 1.79s	remaining: 301ms
# 856:	learn: 0.0464435	total: 1.79s	remaining: 299ms
# 857:	learn: 0.0464184	total: 1.79s	remaining: 296ms
# 858:	learn: 0.0463776	total: 1.79s	remaining: 294ms
# 859:	learn: 0.0463462	total: 1.79s	remaining: 292ms
# 860:	learn: 0.0463065	total: 1.8s	remaining: 290ms
# 861:	learn: 0.0462338	total: 1.8s	remaining: 288ms
# 862:	learn: 0.0461725	total: 1.8s	remaining: 286ms
# 863:	learn: 0.0461252	total: 1.8s	remaining: 284ms
# 864:	learn: 0.0460708	total: 1.8s	remaining: 282ms
# 865:	learn: 0.0460509	total: 1.8s	remaining: 279ms
# 866:	learn: 0.0459915	total: 1.81s	remaining: 277ms
# 867:	learn: 0.0459330	total: 1.81s	remaining: 275ms
# 868:	learn: 0.0458945	total: 1.81s	remaining: 273ms
# 869:	learn: 0.0458539	total: 1.81s	remaining: 271ms
# 870:	learn: 0.0458220	total: 1.81s	remaining: 269ms
# 871:	learn: 0.0457591	total: 1.82s	remaining: 267ms
# 872:	learn: 0.0457358	total: 1.82s	remaining: 264ms
# 873:	learn: 0.0456978	total: 1.82s	remaining: 262ms
# 874:	learn: 0.0456656	total: 1.82s	remaining: 260ms
# 875:	learn: 0.0456055	total: 1.82s	remaining: 258ms
# 876:	learn: 0.0455395	total: 1.82s	remaining: 256ms
# 877:	learn: 0.0455057	total: 1.83s	remaining: 254ms
# 878:	learn: 0.0454807	total: 1.83s	remaining: 252ms
# 879:	learn: 0.0454252	total: 1.83s	remaining: 250ms
# 880:	learn: 0.0453899	total: 1.83s	remaining: 247ms
# 881:	learn: 0.0453807	total: 1.83s	remaining: 245ms
# 882:	learn: 0.0453415	total: 1.83s	remaining: 243ms
# 883:	learn: 0.0453096	total: 1.84s	remaining: 241ms
# 884:	learn: 0.0452670	total: 1.84s	remaining: 239ms
# 885:	learn: 0.0452177	total: 1.84s	remaining: 237ms
# 886:	learn: 0.0451783	total: 1.84s	remaining: 235ms
# 887:	learn: 0.0451498	total: 1.84s	remaining: 232ms
# 888:	learn: 0.0451077	total: 1.84s	remaining: 230ms
# 889:	learn: 0.0450673	total: 1.85s	remaining: 228ms
# 890:	learn: 0.0450175	total: 1.85s	remaining: 226ms
# 891:	learn: 0.0449899	total: 1.85s	remaining: 224ms
# 892:	learn: 0.0449401	total: 1.85s	remaining: 222ms
# 893:	learn: 0.0449018	total: 1.85s	remaining: 220ms
# 894:	learn: 0.0448591	total: 1.86s	remaining: 218ms
# 895:	learn: 0.0448055	total: 1.86s	remaining: 216ms
# 896:	learn: 0.0447808	total: 1.86s	remaining: 214ms
# 897:	learn: 0.0447639	total: 1.86s	remaining: 211ms
# 898:	learn: 0.0447243	total: 1.86s	remaining: 209ms
# 899:	learn: 0.0446887	total: 1.86s	remaining: 207ms
# 900:	learn: 0.0446701	total: 1.87s	remaining: 205ms
# 901:	learn: 0.0446301	total: 1.87s	remaining: 203ms
# 902:	learn: 0.0445746	total: 1.87s	remaining: 201ms
# 903:	learn: 0.0445159	total: 1.87s	remaining: 199ms
# 904:	learn: 0.0444633	total: 1.87s	remaining: 197ms
# 905:	learn: 0.0444284	total: 1.88s	remaining: 195ms
# 906:	learn: 0.0444086	total: 1.88s	remaining: 192ms
# 907:	learn: 0.0443768	total: 1.88s	remaining: 190ms
# 908:	learn: 0.0443327	total: 1.88s	remaining: 188ms
# 909:	learn: 0.0443028	total: 1.88s	remaining: 186ms
# 910:	learn: 0.0442899	total: 1.88s	remaining: 184ms
# 911:	learn: 0.0442590	total: 1.89s	remaining: 182ms
# 912:	learn: 0.0442197	total: 1.89s	remaining: 180ms
# 913:	learn: 0.0441754	total: 1.89s	remaining: 178ms
# 914:	learn: 0.0441327	total: 1.89s	remaining: 176ms
# 915:	learn: 0.0441048	total: 1.89s	remaining: 174ms
# 916:	learn: 0.0440455	total: 1.9s	remaining: 172ms
# 917:	learn: 0.0439931	total: 1.9s	remaining: 169ms
# 918:	learn: 0.0439654	total: 1.9s	remaining: 167ms
# 919:	learn: 0.0439276	total: 1.9s	remaining: 165ms
# 920:	learn: 0.0438932	total: 1.9s	remaining: 163ms
# 921:	learn: 0.0438557	total: 1.9s	remaining: 161ms
# 922:	learn: 0.0438173	total: 1.91s	remaining: 159ms
# 923:	learn: 0.0438104	total: 1.91s	remaining: 157ms
# 924:	learn: 0.0437810	total: 1.91s	remaining: 155ms
# 925:	learn: 0.0437507	total: 1.93s	remaining: 154ms
# 926:	learn: 0.0437088	total: 1.93s	remaining: 152ms
# 927:	learn: 0.0436644	total: 1.93s	remaining: 150ms
# 928:	learn: 0.0436102	total: 1.93s	remaining: 148ms
# 929:	learn: 0.0435595	total: 1.93s	remaining: 146ms
# 930:	learn: 0.0435099	total: 1.94s	remaining: 143ms
# 931:	learn: 0.0434812	total: 1.94s	remaining: 141ms
# 932:	learn: 0.0434224	total: 1.94s	remaining: 139ms
# 933:	learn: 0.0434149	total: 1.94s	remaining: 137ms
# 934:	learn: 0.0433754	total: 1.94s	remaining: 135ms
# 935:	learn: 0.0433472	total: 1.94s	remaining: 133ms
# 936:	learn: 0.0433156	total: 1.95s	remaining: 131ms
# 937:	learn: 0.0432985	total: 1.95s	remaining: 129ms
# 938:	learn: 0.0432565	total: 1.95s	remaining: 127ms
# 939:	learn: 0.0432280	total: 1.95s	remaining: 125ms
# 940:	learn: 0.0431829	total: 1.95s	remaining: 122ms
# 941:	learn: 0.0431481	total: 1.96s	remaining: 120ms
# 942:	learn: 0.0430935	total: 1.96s	remaining: 118ms
# 943:	learn: 0.0430634	total: 1.96s	remaining: 116ms
# 944:	learn: 0.0430113	total: 1.96s	remaining: 114ms
# 945:	learn: 0.0429943	total: 1.96s	remaining: 112ms
# 946:	learn: 0.0429580	total: 1.96s	remaining: 110ms
# 947:	learn: 0.0429153	total: 1.97s	remaining: 108ms
# 948:	learn: 0.0428962	total: 1.97s	remaining: 106ms
# 949:	learn: 0.0428689	total: 1.97s	remaining: 104ms
# 950:	learn: 0.0428101	total: 1.97s	remaining: 102ms
# 951:	learn: 0.0427857	total: 1.97s	remaining: 99.5ms
# 952:	learn: 0.0427434	total: 1.97s	remaining: 97.4ms
# 953:	learn: 0.0427144	total: 1.98s	remaining: 95.3ms
# 954:	learn: 0.0426918	total: 1.98s	remaining: 93.2ms
# 955:	learn: 0.0426812	total: 1.98s	remaining: 91.1ms
# 956:	learn: 0.0426599	total: 1.98s	remaining: 89ms
# 957:	learn: 0.0426134	total: 1.98s	remaining: 86.9ms
# 958:	learn: 0.0425560	total: 1.99s	remaining: 84.9ms
# 959:	learn: 0.0425256	total: 1.99s	remaining: 82.8ms
# 960:	learn: 0.0424867	total: 1.99s	remaining: 80.7ms
# 961:	learn: 0.0424685	total: 1.99s	remaining: 78.6ms
# 962:	learn: 0.0424506	total: 1.99s	remaining: 76.5ms
# 963:	learn: 0.0424376	total: 1.99s	remaining: 74.5ms
# 964:	learn: 0.0423935	total: 2s	remaining: 72.4ms
# 965:	learn: 0.0423409	total: 2s	remaining: 70.3ms
# 966:	learn: 0.0423020	total: 2s	remaining: 68.2ms
# 967:	learn: 0.0422522	total: 2s	remaining: 66.1ms
# 968:	learn: 0.0422212	total: 2s	remaining: 64.1ms
# 969:	learn: 0.0421825	total: 2s	remaining: 62ms
# 970:	learn: 0.0421329	total: 2.01s	remaining: 59.9ms
# 971:	learn: 0.0420968	total: 2.01s	remaining: 57.8ms
# 972:	learn: 0.0420638	total: 2.01s	remaining: 55.8ms
# 973:	learn: 0.0420146	total: 2.01s	remaining: 53.7ms
# 974:	learn: 0.0419705	total: 2.01s	remaining: 51.6ms
# 975:	learn: 0.0419500	total: 2.01s	remaining: 49.5ms
# 976:	learn: 0.0418955	total: 2.02s	remaining: 47.5ms
# 977:	learn: 0.0418526	total: 2.02s	remaining: 45.4ms
# 978:	learn: 0.0418300	total: 2.02s	remaining: 43.3ms
# 979:	learn: 0.0418096	total: 2.02s	remaining: 41.3ms
# 980:	learn: 0.0417931	total: 2.02s	remaining: 39.2ms
# 981:	learn: 0.0417560	total: 2.02s	remaining: 37.1ms
# 982:	learn: 0.0417311	total: 2.03s	remaining: 35.1ms
# 983:	learn: 0.0417008	total: 2.03s	remaining: 33ms
# 984:	learn: 0.0416739	total: 2.03s	remaining: 30.9ms
# 985:	learn: 0.0416569	total: 2.03s	remaining: 28.9ms
# 986:	learn: 0.0416080	total: 2.03s	remaining: 26.8ms
# 987:	learn: 0.0415812	total: 2.04s	remaining: 24.7ms
# 988:	learn: 0.0415339	total: 2.04s	remaining: 22.7ms
# 989:	learn: 0.0414903	total: 2.04s	remaining: 20.6ms
# 990:	learn: 0.0414703	total: 2.04s	remaining: 18.5ms
# 991:	learn: 0.0414347	total: 2.04s	remaining: 16.5ms
# 992:	learn: 0.0413997	total: 2.04s	remaining: 14.4ms
# 993:	learn: 0.0413672	total: 2.04s	remaining: 12.3ms
# 994:	learn: 0.0413391	total: 2.05s	remaining: 10.3ms
# 995:	learn: 0.0413062	total: 2.05s	remaining: 8.23ms
# 996:	learn: 0.0412760	total: 2.05s	remaining: 6.17ms
# 997:	learn: 0.0412321	total: 2.05s	remaining: 4.11ms
# 998:	learn: 0.0412209	total: 2.05s	remaining: 2.06ms
# 999:	learn: 0.0411786	total: 2.06s	remaining: 0us

# %%
model_value = pd.DataFrame()
for key, value in best_model.items():
    model_value[key] = value

# %%
model_value
# Out:
#            lgb      Ridge      Lasso        xgb        rgb        cat
# 0    11.899711  11.898468  11.980633  11.821405  11.816413  11.847848
# 1    12.581841  12.581141  12.175316  12.855978  12.774139  12.802837
# 2    11.716350  11.718764  11.754549  11.615332  11.699914  11.611477
# 3    11.988405  11.987919  11.880151  12.079696  12.008236  12.057154
# 4    12.665144  12.665834  12.256957  12.655875  12.659357  12.772644
# ..         ...        ...        ...        ...        ...        ...
# 287  11.618285  11.615636  11.817350  11.576105  11.521389  11.603914
# 288  12.507376  12.507552  12.244397  12.483284  12.393883  12.428031
# 289  12.303170  12.307796  12.244397  12.074965  12.084002  12.105706
# 290  11.834282  11.832890  11.836190  11.768435  11.824765  11.715051
# 291  11.684471  11.686201  12.024593  11.705474  11.649914  11.662217
#
# [292 rows x 6 columns]

# %%
best_model = pd.DataFrame(best_model.items())

# %%
final_cat = XGBRegressor()
final_cat.fit(model_value, y_test)
final=final_cat.predict(model_value)

# %%
RMSE = mean_squared_error(final, y_test)**0.5
print(RMSE)
# Out:
# 0.007131316459405058
